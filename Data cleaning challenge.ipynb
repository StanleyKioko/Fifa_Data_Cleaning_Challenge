# %% [markdown]
# # Data cleaning challenge

# %% [markdown]
# Importing the libraries that I will be using

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv("fifa21 raw data v2.csv");
# Out:
# C:\Users\mwang\AppData\Local\Temp\ipykernel_1264\1460144195.py:1: DtypeWarning: Columns (76) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("fifa21 raw data v2.csv");

# %%
df.head()
# Out:
#        ID               Name                      LongName  \
# 0  158023           L. Messi                  Lionel Messi
# 1   20801  Cristiano Ronaldo  C. Ronaldo dos Santos Aveiro
# 2  200389           J. Oblak                     Jan Oblak
# 3  192985       K. De Bruyne               Kevin De Bruyne
# 4  190871          Neymar Jr    Neymar da Silva Santos Jr.
#
#                                            photoUrl  \
# 0  https://cdn.sofifa.com/players/158/023/21_60.png
# 1  https://cdn.sofifa.com/players/020/801/21_60.png
# 2  https://cdn.sofifa.com/players/200/389/21_60.png
# 3  https://cdn.sofifa.com/players/192/985/21_60.png
# 4  https://cdn.sofifa.com/players/190/871/21_60.png
#
#                                            playerUrl Nationality  Age  ↓OVA  \
# 0  http://sofifa.com/player/158023/lionel-messi/2...   Argentina   33    93
# 1  http://sofifa.com/player/20801/c-ronaldo-dos-s...    Portugal   35    92
# ...

# %% [markdown]
# # Data Dictionary

# %% [markdown]
# Photourl:Web address where the players photo can be found

# %% [markdown]
# Longname: Players full name including any middle name or initials

# %% [markdown]
# Nationality: The country the player represents or is from

# %% [markdown]
# Positions:The various positions in the field the player is capable of playing.

# %% [markdown]
# name: The players name

# %% [markdown]
# Age:The players curent age in years

# %% [markdown]
# OVA: Ovarall rating, a score that shows the players overall ability.

# %% [markdown]
# POT: Potentials rating. A score that shos the players potential to improve.

# %% [markdown]
# Team & Contract: The team the player is currently playing for and details for the contract.

# %% [markdown]
# ID: A unique identfier assigned to the player.

# %% [markdown]
# Height: The players height in feet and inches and Centimeters.

# %% [markdown]
# Weight: The players weight in pounds or kilograms.

# %% [markdown]
# foot: The players prefered foot for kicking the ball (left or right)

# %% [markdown]
# BOV:Best Ovarall rating,the highest OVA the player has achieved in their career

# %% [markdown]
# BP: Best position, the position the player is best suited for playing

# %% [markdown]
# Growth: The potential growth of the playerin terms of their overall rating.

# %% [markdown]
# Joined:The date the player joined the club.

# %% [markdown]
# Loan date End: The date the player's current loan agrrement ends if applicable.

# %% [markdown]
# Value: The estimated market value of the player

# %% [markdown]
# Wage: the players current salary

# %% [markdown]
# Release clause: The amount of money a team must buy to buy out a player contract

# %% [markdown]
# Attacking: A category of statistics that measures a players ability to contribute to the team's attacking play.

# %% [markdown]
# Crossing: The accuracy of the players croses.

# %% [markdown]
# Finishing: The accuracy of the player's short on goal.

# %% [markdown]
# Heading accuracy: The accuraccy of the players headers.

# %% [markdown]
# Short passing: The accuracy of a players short passes.

# %% [markdown]
# Volleys: The accuracy of the players volleys.

# %% [markdown]
# Skill: A category of statistics that measures a player's technical skills

# %% [markdown]
# Dribbling:A player's ability to dribble past opponents.

# %% [markdown]
# Curve: The amount of curve a player can put on the ball.

# %% [markdown]
# IFK accuracy:The accuracy of the player's free kicks.

# %% [markdown]
# Long passing: The accuracy of a plyer's long passes.

# %% [markdown]
# Ball control:A p;ayer's ability to control the ball.

# %% [markdown]
# Movement: A category of statistics that measures a player's physical abilities.

# %% [markdown]
# Acceleration: How quickly a player can reach their top speed.

# %% [markdown]
# Sprint speed: A players top speed.

# %% [markdown]
# Agility: A player's ability to change their direction quickly./

# %% [markdown]
# Reactions: How quickly a player reacts to situations in the field.

# %% [markdown]
# Balance: A player's ability to maintain balance while running or changing direction.

# %% [markdown]
# Power: A player's physical strength.

# %% [markdown]
# Shot power: The power a player can put behind the shots.

# %% [markdown]
# Jumping:A payer's ability to jump.

# %% [markdown]
# Stamina: How much energy a pplayer has to expend before becomingfatigued.

# %% [markdown]
# Strength: A player's overall physical strength.

# %% [markdown]
# Long shots: A player's ability to take long shots.

# %% [markdown]
# Mentality: A category of statistics that measures a player's mental abilities.

# %% [markdown]
# Aggression: How aggressive  a player plays.

# %% [markdown]
# Interceptions: A player's ability to intercept passes.

# %% [markdown]
# Positioning: How well a player positions themselves on the field.

# %% [markdown]
# Vision: A player's ability to see the field and anticipate plays.

# %% [markdown]
# Penalties: A player

# %% [markdown]
# Describing the data so as to see the mean, variance, and the standard deviation of the variuos columns

# %%
df.describe()
# Out:
#                   ID           Age          ↓OVA           POT           BOV  \
# count   18979.000000  18979.000000  18979.000000  18979.000000  18979.000000
# mean   226403.384794     25.194109     65.718636     71.136414     66.751726
# std     27141.054157      4.710520      6.968999      6.114635      6.747193
# min        41.000000     16.000000     47.000000     47.000000     48.000000
# 25%    210135.000000     21.000000     61.000000     67.000000     62.000000
# 50%    232418.000000     25.000000     66.000000     71.000000     67.000000
# 75%    246922.500000     29.000000     70.000000     75.000000     71.000000
# max    259216.000000     53.000000     93.000000     95.000000     93.000000
#
#           Attacking      Crossing     Finishing  Heading Accuracy  \
# count  18979.000000  18979.000000  18979.000000      18979.000000
# mean     248.938142     49.688392     45.842405         51.942726
# std       74.299428     18.131153     19.567081         17.294409
# ...

# %% [markdown]
# Checking the shape of the data

# %%
df.shape
# Out:
# (18979, 77)

# %% [markdown]
# The data has 77 columns and 18979 rows

# %%
df.columns
# Out:
# Index(['ID', 'Name', 'LongName', 'photoUrl', 'playerUrl', 'Nationality', 'Age',
#        '↓OVA', 'POT', 'Club', 'Contract', 'Positions', 'Height', 'Weight',
#        'Preferred Foot', 'BOV', 'Best Position', 'Joined', 'Loan Date End',
#        'Value', 'Wage', 'Release Clause', 'Attacking', 'Crossing', 'Finishing',
#        'Heading Accuracy', 'Short Passing', 'Volleys', 'Skill', 'Dribbling',
#        'Curve', 'FK Accuracy', 'Long Passing', 'Ball Control', 'Movement',
#        'Acceleration', 'Sprint Speed', 'Agility', 'Reactions', 'Balance',
#        'Power', 'Shot Power', 'Jumping', 'Stamina', 'Strength', 'Long Shots',
#        'Mentality', 'Aggression', 'Interceptions', 'Positioning', 'Vision',
#        'Penalties', 'Composure', 'Defending', 'Marking', 'Standing Tackle',
#        'Sliding Tackle', 'Goalkeeping', 'GK Diving', 'GK Handling',
#        'GK Kicking', 'GK Positioning', 'GK Reflexes', 'Total Stats',
# ...

# %% [markdown]
# Since the dataset has soo many columns i have decided to form different datasets using the same columns so I can work on them,
# Clean them
# and merge the finall selected columns later

# %% [markdown]
# # Extracting columns for the first set

# %%
df1 = df[['ID', 'Name', 'LongName', 'photoUrl', 'playerUrl', 'Nationality', 'Age',
       '↓OVA', 'POT', 'Club']]

# %%
df1.head()
# Out:
#        ID               Name                      LongName  \
# 0  158023           L. Messi                  Lionel Messi
# 1   20801  Cristiano Ronaldo  C. Ronaldo dos Santos Aveiro
# 2  200389           J. Oblak                     Jan Oblak
# 3  192985       K. De Bruyne               Kevin De Bruyne
# 4  190871          Neymar Jr    Neymar da Silva Santos Jr.
#
#                                            photoUrl  \
# 0  https://cdn.sofifa.com/players/158/023/21_60.png
# 1  https://cdn.sofifa.com/players/020/801/21_60.png
# 2  https://cdn.sofifa.com/players/200/389/21_60.png
# 3  https://cdn.sofifa.com/players/192/985/21_60.png
# 4  https://cdn.sofifa.com/players/190/871/21_60.png
#
#                                            playerUrl Nationality  Age  ↓OVA  \
# 0  http://sofifa.com/player/158023/lionel-messi/2...   Argentina   33    93
# 1  http://sofifa.com/player/20801/c-ronaldo-dos-s...    Portugal   35    92
# ...

# %%
df1.shape
# Out:
# (18979, 10)

# %% [markdown]
# # Checking for duplicates on the datset

# %%
df1.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Great! the dataset has no duplicated values

# %%
df.isna().sum()
# Out:
# ID              0
# Name            0
# LongName        0
# photoUrl        0
# playerUrl       0
#              ...
# PAS             0
# DRI             0
# DEF             0
# PHY             0
# Hits         2595
# Length: 77, dtype: int64

# %% [markdown]
# # Checking for the Mising values in the variuos columns

# %%
df1.isna().sum()
# Out:
# ID             0
# Name           0
# LongName       0
# photoUrl       0
# playerUrl      0
# Nationality    0
# Age            0
# ↓OVA           0
# POT            0
# Club           0
# dtype: int64

# %% [markdown]
# The first classification of the columns has no missing values

# %% [markdown]
# Now check for the unique values in the columns

# %%
df1['↓OVA'].unique()
# Out:
# array([93, 92, 91, 90, 89, 88, 87, 86, 85, 84, 83, 82, 81, 80, 79, 78, 77,
#        76, 75, 74, 73, 72, 71, 70, 69, 68, 67, 66, 65, 64, 63, 62, 61, 60,
#        59, 58, 57, 56, 55, 54, 53, 52, 51, 50, 49, 48, 47], dtype=int64)

# %%
df1['POT'].unique()
# Out:
# array([93, 92, 91, 90, 95, 89, 88, 87, 86, 85, 84, 83, 82, 81, 80, 79, 78,
#        77, 76, 75, 74, 73, 72, 71, 70, 69, 68, 67, 66, 65, 64, 63, 62, 61,
#        60, 59, 58, 57, 56, 55, 54, 53, 52, 51, 50, 49, 48, 47],
#       dtype=int64)

# %%
df1['Club'].unique()
# Out:
# array(['\n\n\n\nFC Barcelona', '\n\n\n\nJuventus',
#        '\n\n\n\nAtlético Madrid', '\n\n\n\nManchester City',
#        '\n\n\n\nParis Saint-Germain', '\n\n\n\nFC Bayern München',
#        '\n\n\n\nLiverpool', '\n\n\n\nReal Madrid', '\n\n\n\nChelsea',
#        '\n\n\n\nTottenham Hotspur', '\n\n\n\nInter', '\n\n\n\nNapoli',
#        '\n\n\n\nBorussia Dortmund', '\n\n\n\nManchester United',
#        '\n\n\n\nArsenal', '\n\n\n\nLazio', '\n\n\n\nLeicester City',
#        '\n\n\n\nBorussia Mönchengladbach', '\n\n\n\nReal Sociedad',
#        '\n\n\n\nAtalanta', '\n\n\n\nOlympique Lyonnais', '\n\n\n\nMilan',
#        '\n\n\n\nVillarreal CF', '\n\n\n\nRB Leipzig', '\n\n\n\nCagliari',
#        '\n\n\n\nAjax', '\n\n\n\nSL Benfica', '\n\n\n\nAS Monaco',
#        '\n\n\n\nWolverhampton Wanderers', '\n\n\n\nEverton',
#        '\n\n\n\nFiorentina', '\n\n\n\nFC Porto', '\n\n\n\nRC Celta',
#        '\n\n\n\nTorino', '\n\n\n\nSevilla FC', '\n\n\n\nGrêmio',
# ...

# %% [markdown]
# # Dealing with outliers and anormalies

# %% [markdown]
# # Age column

# %%
# boxplot of age column

df1.boxplot(column= 'Age')
plt.ylabel("Player's Age")
plt.title("Player's Age Boxplot")
plt.show()

# %%
# First quartile\
Q1 = df1['Age'].quantile(0.25)

# Second Quartile

Q3 = df1['Age'].quantile(0.75)

# interquartile range

IQR = Q3 - Q1

# IQR
IQR
# Out:
# 8.0

# %%
# whisker width

whisker_width = 1.5


# get the outlier records in dataset

age_outliers = df1[(df1['Age'] < (Q1 - (whisker_width*IQR))) | (df1['Age'] > (Q3 + (whisker_width*IQR)))]


# records with Age outliers

age_outliers['Age'].to_list()
# Out:
# [42, 42, 42, 42, 43, 43, 42, 53]

# %%
# list of age outliers

age_outliers['Age'].to_list()
# Out:
# [42, 42, 42, 42, 43, 43, 42, 53]

# %% [markdown]
# -From the boxplot most of the players are aged between 21-41 years.

# %% [markdown]
# -The outliers in age were those ages greater than 41.

# %% [markdown]
# -From the array of the ages that were classified as outliers from the boxplot indicates mostplayers are aged below 42 years.

# %% [markdown]
# Let's now drop the outliers

# %%
# whisker width
whisker_width = 1.5

# get the outlier records in dataset
age_outliers = df1[(df1['Age'] < (Q1 - (whisker_width*IQR))) | (df1['Age'] > (Q3 + (whisker_width*IQR)))]

# drop the outliers
df1 = df1.drop(age_outliers.index)

# show the updated boxplot without outliers
df1.boxplot(column='Age')
plt.ylabel("Player's Age")
plt.title("Player's Age Boxplot (without outliers)")
plt.show()

# %% [markdown]
# Great! The outliers have been eliminated successfully

# %% [markdown]
# # Who are the players?

# %%
# histogram plot to visualize age distribution of the players

sns.histplot(data=df1, x= "Age", bins = 5)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Count'>

# %% [markdown]
# From the above histogram, most players are young

# %% [markdown]
# Saving the dataset

# %%
# Save the dataset to a CSV file
df1.to_csv('df9_dataset.csv', index=False)

# %% [markdown]
# # Extracting other columns for the second dataset

# %%
df.columns
# Out:
# Index(['ID', 'Name', 'LongName', 'photoUrl', 'playerUrl', 'Nationality', 'Age',
#        '↓OVA', 'POT', 'Club', 'Contract', 'Positions', 'Height', 'Weight',
#        'Preferred Foot', 'BOV', 'Best Position', 'Joined', 'Loan Date End',
#        'Value', 'Wage', 'Release Clause', 'Attacking', 'Crossing', 'Finishing',
#        'Heading Accuracy', 'Short Passing', 'Volleys', 'Skill', 'Dribbling',
#        'Curve', 'FK Accuracy', 'Long Passing', 'Ball Control', 'Movement',
#        'Acceleration', 'Sprint Speed', 'Agility', 'Reactions', 'Balance',
#        'Power', 'Shot Power', 'Jumping', 'Stamina', 'Strength', 'Long Shots',
#        'Mentality', 'Aggression', 'Interceptions', 'Positioning', 'Vision',
#        'Penalties', 'Composure', 'Defending', 'Marking', 'Standing Tackle',
#        'Sliding Tackle', 'Goalkeeping', 'GK Diving', 'GK Handling',
#        'GK Kicking', 'GK Positioning', 'GK Reflexes', 'Total Stats',
# ...

# %%
df2 = df[['Contract', 'Positions', 'Height', 'Weight',
       'Preferred Foot', 'BOV', 'Best Position', 'Joined', 'Loan Date End',
       'Value']]

# %%
df2.head()
# Out:
#       Contract   Positions Height Weight Preferred Foot  BOV Best Position  \
# 0  2004 ~ 2021  RW, ST, CF  170cm   72kg           Left   93            RW
# 1  2018 ~ 2022      ST, LW  187cm   83kg          Right   92            ST
# 2  2014 ~ 2023          GK  188cm   87kg          Right   91            GK
# 3  2015 ~ 2023     CAM, CM  181cm   70kg          Right   91           CAM
# 4  2017 ~ 2022     LW, CAM  175cm   68kg          Right   91            LW
#
#          Joined Loan Date End    Value
# 0   Jul 1, 2004           NaN  €103.5M
# 1  Jul 10, 2018           NaN     €63M
# 2  Jul 16, 2014           NaN    €120M
# 3  Aug 30, 2015           NaN    €129M
# 4   Aug 3, 2017           NaN    €132M

# %%
df2.describe()
# Out:
#                 BOV
# count  18979.000000
# mean      66.751726
# std        6.747193
# min       48.000000
# 25%       62.000000
# 50%       67.000000
# 75%       71.000000
# max       93.000000

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18979 entries, 0 to 18978
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Contract        18979 non-null  object
#  1   Positions       18979 non-null  object
#  2   Height          18979 non-null  object
#  3   Weight          18979 non-null  object
#  4   Preferred Foot  18979 non-null  object
#  5   BOV             18979 non-null  int64
#  6   Best Position   18979 non-null  object
#  7   Joined          18979 non-null  object
#  8   Loan Date End   1013 non-null   object
#  9   Value           18979 non-null  object
# dtypes: int64(1), object(9)
# memory usage: 1.4+ MB

# %%
df2.dtypes
# Out:
# Contract          object
# Positions         object
# Height            object
# Weight            object
# Preferred Foot    object
# BOV                int64
# Best Position     object
# Joined            object
# Loan Date End     object
# Value             object
# dtype: object

# %%
df2.isna().sum()
# Out:
# Contract              0
# Positions             0
# Height                0
# Weight                0
# Preferred Foot        0
# BOV                   0
# Best Position         0
# Joined                0
# Loan Date End     17966
# Value                 0
# dtype: int64

# %% [markdown]
# The loan end date column has soo many missing values

# %%
# Visualizing missing values in a heatmap

sns.heatmap(df2.isnull(),yticklabels=False,cbar=False)
# Out:
# <AxesSubplot:>

# %% [markdown]
# From the above Visualization, The loan End date has soo many missing values so I decide to drop it

# %%
# Drop the Loan Date end column column
df2 = df2.drop(['Loan Date End'], axis=1)

# %%
#Checking if the column has bee dropped successfully
df2.columns
# Out:
# Index(['Contract', 'Positions', 'Height', 'Weight', 'Preferred Foot', 'BOV',
#        'Best Position', 'Joined', 'Value'],
#       dtype='object')

# %% [markdown]
# Perfect! The column has been removed successfully. Now lets check if thee is any other column with missing values.

# %%
df2.isna().sum()
# Out:
# Contract          0
# Positions         0
# Height            0
# Weight            0
# Preferred Foot    0
# BOV               0
# Best Position     0
# Joined            0
# Value             0
# dtype: int64

# %% [markdown]
# For the remaini g columns non has missing values

# %% [markdown]
# # checking for duplicates in the dataset

# %%
df2.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Great! The dataset has no data duplicates

# %% [markdown]
# # Checking for Unique values on the variuos columns

# %%
#Checking for unique values in the  contract column
df2['Contract'].unique()
# Out:
# array(['2004 ~ 2021', '2018 ~ 2022', '2014 ~ 2023', '2015 ~ 2023',
#        '2017 ~ 2022', '2017 ~ 2023', '2018 ~ 2024', '2014 ~ 2022',
#        '2018 ~ 2023', '2016 ~ 2023', '2013 ~ 2023', '2011 ~ 2023',
#        '2009 ~ 2022', '2005 ~ 2021', '2011 ~ 2021', '2015 ~ 2022',
#        '2017 ~ 2024', '2010 ~ 2024', '2012 ~ 2021', '2019 ~ 2024',
#        '2015 ~ 2024', '2017 ~ 2025', '2020 ~ 2025', '2019 ~ 2023',
#        '2008 ~ 2023', '2015 ~ 2021', '2020 ~ 2022', '2012 ~ 2022',
#        '2016 ~ 2025', '2013 ~ 2022', '2011 ~ 2022', '2012 ~ 2024',
#        '2016 ~ 2021', '2012 ~ 2023', '2008 ~ 2022', '2019 ~ 2022',
#        '2017 ~ 2021', '2013 ~ 2024', '2020 ~ 2024', '2010 ~ 2022',
#        '2020 ~ 2021', '2011 ~ 2024', '2020 ~ 2023', '2014 ~ 2024',
#        '2013 ~ 2026', '2016 ~ 2022', '2010 ~ 2021', '2013 ~ 2021',
#        '2019 ~ 2025', '2018 ~ 2025', '2016 ~ 2024', '2018 ~ 2021',
#        '2009 ~ 2024', '2007 ~ 2022', 'Jun 30, 2021 On Loan',
# ...

# %%
#Checking for unique values in the  positions column
df2['Positions'].unique()
# Out:
# array(['RW, ST, CF', 'ST, LW', 'GK', 'CAM, CM', 'LW, CAM', 'ST', 'RW',
#        'ST, LW, RW', 'CB', 'LW', 'CDM', 'CF, ST', 'LW, RW', 'CDM, CM',
#        'CDM, RB', 'CF, CAM', 'LW, ST', 'CM', 'ST, CF, LW', 'RM, LM, CAM',
#        'RB', 'RW, CAM, CM', 'LB', 'LM, CF', 'CF', 'RW, LW', 'CAM, RM, RW',
#        'CM, CDM', 'CAM, CF, ST', 'CM, CDM, CAM', 'CF, LW, CAM',
#        'CAM, RM, CF', 'LM, ST', 'RM, LM, RW', 'LM', 'CAM, RW', 'CB, CDM',
#        'RW, RM', 'LW, CF', 'CM, RM, LM', 'LB, LM', 'CAM, CM, RM',
#        'CAM, CM, CF', 'CAM, CF', 'LM, RM, LW', 'LM, LB, CM', 'CM, LM, LB',
#        'RM, RW', 'RM, CM', 'CAM, CM, LW', 'CB, LB', 'RM, RB', 'ST, RW',
#        'LM, RW, LW', 'RB, LB', 'RB, RM', 'RM', 'LM, RM, CF', 'CAM, RM',
#        'RB, RWB', 'CDM, CB, CM', 'CAM, RM, ST', 'LM, LW, RM', 'CM, CAM',
#        'ST, RM, CF', 'LM, RM', 'RM, CF', 'LM, LWB', 'RW, RM, CF',
#        'RB, CM', 'LW, CAM, RW', 'CAM, LW, CM', 'CM, CAM, CDM',
# ...

# %%
#Checking for unique values in the  Height column
df2['Height'].unique()
# Out:
# array(['170cm', '187cm', '188cm', '181cm', '175cm', '184cm', '191cm',
#        '178cm', '193cm', '185cm', '199cm', '173cm', '168cm', '176cm',
#        '177cm', '183cm', '180cm', '189cm', '179cm', '195cm', '172cm',
#        '182cm', '186cm', '192cm', '165cm', '194cm', '167cm', '196cm',
#        '163cm', '190cm', '174cm', '169cm', '171cm', '197cm', '200cm',
#        '166cm', '6\'2"', '164cm', '198cm', '6\'3"', '6\'5"', '5\'11"',
#        '6\'4"', '6\'1"', '6\'0"', '5\'10"', '5\'9"', '5\'6"', '5\'7"',
#        '5\'4"', '201cm', '158cm', '162cm', '161cm', '160cm', '203cm',
#        '157cm', '156cm', '202cm', '159cm', '206cm', '155cm'], dtype=object)

# %% [markdown]
# Note! there is some inconsistency in the Height column since its recorded in cm and inches

# %% [markdown]
# # Now lets convert the inches to centimeters

# %%
#lets clean height
# height has 2 units of measurement thus cm and ft_inch
# transfor all into centimeters

df2["Height"] = df2["Height"].astype("string")

cm_height = []

for i, height in enumerate(df2["Height"]):
#removing cm unit
    if "cm" in height:
        cm_value = float(height.replace("cm", ""))
        
    else:
        ft_inch = height.replace("\\","").replace("'",".").replace('"',"").split(".")
        ft,inch = float(ft_inch[0]), float(ft_inch[1])
        cm_value = (ft * 30.48) + (inch * 2.54)
    
    cm_height.append(round(cm_value,2))
    
df2["Height"] = cm_height

# %% [markdown]
# Let's confirm if all heights have been converted

# %%
df2['Height'].unique()
# Out:
# array([170.  , 187.  , 188.  , 181.  , 175.  , 184.  , 191.  , 178.  ,
#        193.  , 185.  , 199.  , 173.  , 168.  , 176.  , 177.  , 183.  ,
#        180.  , 189.  , 179.  , 195.  , 172.  , 182.  , 186.  , 192.  ,
#        165.  , 194.  , 167.  , 196.  , 163.  , 190.  , 174.  , 169.  ,
#        171.  , 197.  , 200.  , 166.  , 187.96, 164.  , 198.  , 190.5 ,
#        195.58, 180.34, 193.04, 185.42, 182.88, 177.8 , 175.26, 167.64,
#        170.18, 162.56, 201.  , 158.  , 162.  , 161.  , 160.  , 203.  ,
#        157.  , 156.  , 202.  , 159.  , 206.  , 155.  ])

# %% [markdown]
# Great! THe inches have been converted to cm successfully

# %%
df2.tail(20)
# Out:
#           Contract Positions  Height Weight Preferred Foot  BOV Best Position  \
# 18959  2019 ~ 2021        ST   186.0   70kg          Right   50            ST
# 18960  2019 ~ 2021        RM   180.0   67kg          Right   49            RM
# 18961  2017 ~ 2021        CM   178.0   64kg          Right   50           CAM
# 18962  2020 ~ 2024        CB   176.0   70kg           Left   50            CB
# 18963  2020 ~ 2024        CM   174.0   71kg          Right   51           CAM
# 18964  2020 ~ 2024        GK   185.0   70kg           Left   48            GK
# 18965  2020 ~ 2023        CM   186.0   80kg          Right   51           CDM
# 18966  2019 ~ 2022        CB   185.0   74kg          Right   49            CB
# 18967  2018 ~ 2020        CM   170.0   62kg          Right   49            CM
# 18968  2020 ~ 2022        CM   174.0   68kg          Right   50           CDM
# 18969  2020 ~ 2022        CM   185.0   79kg          Right   49            RM
# ...

# %%
#Checking for unique values in the  weight column
df2['Weight'].unique()
# Out:
# array(['72kg', '83kg', '87kg', '70kg', '68kg', '80kg', '71kg', '91kg',
#        '73kg', '85kg', '92kg', '69kg', '84kg', '96kg', '81kg', '82kg',
#        '75kg', '86kg', '89kg', '74kg', '76kg', '64kg', '78kg', '90kg',
#        '66kg', '60kg', '94kg', '79kg', '67kg', '65kg', '59kg', '61kg',
#        '93kg', '88kg', '97kg', '77kg', '62kg', '63kg', '95kg', '100kg',
#        '58kg', '183lbs', '179lbs', '172lbs', '196lbs', '176lbs', '185lbs',
#        '170lbs', '203lbs', '168lbs', '161lbs', '146lbs', '130lbs',
#        '190lbs', '174lbs', '148lbs', '165lbs', '159lbs', '192lbs',
#        '181lbs', '139lbs', '154lbs', '157lbs', '163lbs', '98kg', '103kg',
#        '99kg', '102kg', '56kg', '101kg', '57kg', '55kg', '104kg', '107kg',
#        '110kg', '53kg', '50kg', '54kg', '52kg'], dtype=object)

# %% [markdown]
# Note again! There is also some inconsistency in the Weight column since the weight of various players is recorded using different measurements

# %%
#Weight
#also has same issue as height
# let standardize all kg as lbs

df2["Weight"] = df2["Weight"].astype("string")

lbs_weight = []

#converting kg to lbs
for i, weight in enumerate(df2["Weight"]):
    if "kg" in weight:
        kg_value = float(weight.replace("kg", ""))
        lbs_value = kg_value * 2.204
    else:
        lbs_value = float(weight.replace("lbs",""))
    
    lbs_weight.append(round(lbs_value,2))

df2["Weight"] = lbs_weight

# %% [markdown]
# Great! The weight column has been converted successfully

# %%
#Checking for unique values in the  Preferred Foot column
df2['Preferred Foot'].unique()
# Out:
# array(['Left', 'Right'], dtype=object)

# %%
#Checking for unique values in the  BOV column
df2['BOV'].unique()
# Out:
# array([93, 92, 91, 90, 89, 88, 87, 86, 85, 84, 83, 82, 81, 80, 79, 78, 77,
#        76, 75, 74, 73, 72, 71, 70, 69, 68, 67, 66, 65, 64, 63, 62, 61, 60,
#        59, 58, 57, 56, 55, 54, 53, 52, 51, 50, 49, 48], dtype=int64)

# %%
#Checking for unique values in the Best Position column
df2['Best Position'].unique()
# Out:
# array(['RW', 'ST', 'GK', 'CAM', 'LW', 'CB', 'CDM', 'CF', 'CM', 'RB', 'LB',
#        'LM', 'RM', 'LWB', 'RWB'], dtype=object)

# %%
#Checking for unique values in the Joined column
df2['Joined'].unique()
# Out:
# array(['Jul 1, 2004', 'Jul 10, 2018', 'Jul 16, 2014', ..., 'Sep 22, 2018',
#        'Feb 28, 2015', 'Mar 6, 2018'], dtype=object)

# %%
#Checking for unique values in the value column
df2['Value'].unique()
# Out:
# array(['€103.5M', '€63M', '€120M', '€129M', '€132M', '€111M', '€120.5M',
#        '€102M', '€185.5M', '€110M', '€113M', '€90.5M', '€82M', '€17.5M',
#        '€83.5M', '€33.5M', '€114.5M', '€78M', '€103M', '€109M', '€92M',
#        '€10M', '€76.5M', '€89.5M', '€87.5M', '€79.5M', '€124M', '€114M',
#        '€95M', '€92.5M', '€105.5M', '€88.5M', '€85M', '€81.5M', '€26M',
#        '€21M', '€56M', '€67.5M', '€53M', '€36.5M', '€51M', '€65.5M',
#        '€46.5M', '€61.5M', '€72.5M', '€77.5M', '€43.5M', '€32.5M', '€36M',
#        '€32M', '€54M', '€49.5M', '€57M', '€66.5M', '€74.5M', '€71.5M',
#        '€121M', '€99M', '€67M', '€86.5M', '€93.5M', '€70M', '€62M',
#        '€66M', '€58M', '€44M', '€81M', '€37M', '€14.5M', '€46M', '€47.5M',
#        '€52.5M', '€54.5M', '€34.5M', '€57.5M', '€51.5M', '€44.5M', '€55M',
#        '€48M', '€60.5M', '€63.5M', '€61M', '€29M', '€58.5M', '€55.5M',
#        '€42M', '€40.5M', '€43M', '€45.5M', '€34M', '€26.5M', '€42.5M',
# ...

# %% [markdown]
# NOTE! The value column has some Inconsistency let's work on it

# %%
#Value
#remove currency sign and value abbrev.

n_val = []
for i in range(len(df["Value"])):
        v = df2["Value"][i]
        v = v.replace("€", "")
        v = v.replace("K","000")
        v = v.replace("M","000_000")
        v = v.replace(".","")     
        n_val.append(int(v))
        
df2["Value"] = n_val

# %% [markdown]
# Let's Confirm if the currency sighn has been eliminated successfully

# %%
#Checking for unique values in the value column
df2['Value'].unique()
# Out:
# array([1035000000,   63000000,  120000000,  129000000,  132000000,
#         111000000, 1205000000,  102000000, 1855000000,  110000000,
#         113000000,  905000000,   82000000,  175000000,  835000000,
#         335000000, 1145000000,   78000000,  103000000,  109000000,
#          92000000,   10000000,  765000000,  895000000,  875000000,
#         795000000,  124000000,  114000000,   95000000,  925000000,
#        1055000000,  885000000,   85000000,  815000000,   26000000,
#          21000000,   56000000,  675000000,   53000000,  365000000,
#          51000000,  655000000,  465000000,  615000000,  725000000,
#         775000000,  435000000,  325000000,   36000000,   32000000,
#          54000000,  495000000,   57000000,  665000000,  745000000,
#         715000000,  121000000,   99000000,   67000000,  865000000,
#         935000000,   70000000,   62000000,   66000000,   58000000,
#          44000000,   81000000,   37000000,  145000000,   46000000,
# ...

# %% [markdown]
# Great! The conversion is successfull

# %%
df2.hist(figsize=(10,8));

# %% [markdown]
# lets draw a paiplot to see how the different variables compare to each other

# %%
sns.pairplot(df2)

# %%
df2.head()
# Out:
#       Contract   Positions  Height  Weight Preferred Foot  BOV Best Position  \
# 0  2004 ~ 2021  RW, ST, CF   170.0  158.69           Left   93            RW
# 1  2018 ~ 2022      ST, LW   187.0  182.93          Right   92            ST
# 2  2014 ~ 2023          GK   188.0  191.75          Right   91            GK
# 3  2015 ~ 2023     CAM, CM   181.0  154.28          Right   91           CAM
# 4  2017 ~ 2022     LW, CAM   175.0  149.87          Right   91            LW
#
#          Joined       Value
# 0   Jul 1, 2004  1035000000
# 1  Jul 10, 2018    63000000
# 2  Jul 16, 2014   120000000
# 3  Aug 30, 2015   129000000
# 4   Aug 3, 2017   132000000

# %% [markdown]
# Saving the dataset

# %%
# Save the dataset to a CSV file
df2.to_csv('df2_dataset.csv', index=False)

# %% [markdown]
# # Extracting other columns for the third dataset

# %%
df.columns
# Out:
# Index(['ID', 'Name', 'LongName', 'photoUrl', 'playerUrl', 'Nationality', 'Age',
#        '↓OVA', 'POT', 'Club', 'Contract', 'Positions', 'Height', 'Weight',
#        'Preferred Foot', 'BOV', 'Best Position', 'Joined', 'Loan Date End',
#        'Value', 'Wage', 'Release Clause', 'Attacking', 'Crossing', 'Finishing',
#        'Heading Accuracy', 'Short Passing', 'Volleys', 'Skill', 'Dribbling',
#        'Curve', 'FK Accuracy', 'Long Passing', 'Ball Control', 'Movement',
#        'Acceleration', 'Sprint Speed', 'Agility', 'Reactions', 'Balance',
#        'Power', 'Shot Power', 'Jumping', 'Stamina', 'Strength', 'Long Shots',
#        'Mentality', 'Aggression', 'Interceptions', 'Positioning', 'Vision',
#        'Penalties', 'Composure', 'Defending', 'Marking', 'Standing Tackle',
#        'Sliding Tackle', 'Goalkeeping', 'GK Diving', 'GK Handling',
#        'GK Kicking', 'GK Positioning', 'GK Reflexes', 'Total Stats',
# ...

# %%
df3 = df[['Wage', 'Release Clause', 'Attacking', 'Crossing', 'Finishing',
       'Heading Accuracy', 'Short Passing', 'Volleys', 'Skill', 'Dribbling']]

# %%
df3.head()
# Out:
#     Wage Release Clause  Attacking  Crossing  Finishing  Heading Accuracy  \
# 0  €560K        €138.4M        429        85         95                70
# 1  €220K         €75.9M        437        84         95                90
# 2  €125K        €159.4M         95        13         11                15
# 3  €370K          €161M        407        94         82                55
# 4  €270K        €166.5M        408        85         87                62
#
#    Short Passing  Volleys  Skill  Dribbling
# 0             91       88    470         96
# 1             82       86    414         88
# 2             43       13    109         12
# 3             94       82    441         88
# 4             87       87    448         95

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18979 entries, 0 to 18978
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Wage              18979 non-null  object
#  1   Release Clause    18979 non-null  object
#  2   Attacking         18979 non-null  int64
#  3   Crossing          18979 non-null  int64
#  4   Finishing         18979 non-null  int64
#  5   Heading Accuracy  18979 non-null  int64
#  6   Short Passing     18979 non-null  int64
#  7   Volleys           18979 non-null  int64
#  8   Skill             18979 non-null  int64
#  9   Dribbling         18979 non-null  int64
# dtypes: int64(8), object(2)
# memory usage: 1.4+ MB

# %%
df3.dtypes
# Out:
# Wage                object
# Release Clause      object
# Attacking            int64
# Crossing             int64
# Finishing            int64
# Heading Accuracy     int64
# Short Passing        int64
# Volleys              int64
# Skill                int64
# Dribbling            int64
# dtype: object

# %%
df3.isna().sum()
# Out:
# Wage                0
# Release Clause      0
# Attacking           0
# Crossing            0
# Finishing           0
# Heading Accuracy    0
# Short Passing       0
# Volleys             0
# Skill               0
# Dribbling           0
# dtype: int64

# %% [markdown]
# Great! There are no missing values on the selected columns

# %%
df3.describe()
# Out:
#           Attacking      Crossing     Finishing  Heading Accuracy  \
# count  18979.000000  18979.000000  18979.000000      18979.000000
# mean     248.938142     49.688392     45.842405         51.942726
# std       74.299428     18.131153     19.567081         17.294409
# min       42.000000      6.000000      3.000000          5.000000
# 25%      222.000000     38.000000     30.000000         44.000000
# 50%      263.000000     54.000000     49.000000         55.000000
# 75%      297.000000     63.000000     62.000000         64.000000
# max      437.000000     94.000000     95.000000         93.000000
#
#        Short Passing       Volleys         Skill     Dribbling
# count   18979.000000  18979.000000  18979.000000  18979.000000
# mean       58.768112     42.696507    256.479214     55.587491
# std        14.519106     17.646937     78.650601     18.761314
# min         7.000000      3.000000     40.000000      5.000000
# ...

# %%
df3.duplicated().sum()
# Out:
# 3

# %% [markdown]
# Let's now delete the duplicates

# %%
# remove duplicates based on all columns
df3 = df3.drop_duplicates()

# %%
#checking if the columns have been removed
df3.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Great! The duplicates have successfully been removed

# %%
df3.head()
# Out:
#     Wage Release Clause  Attacking  Crossing  Finishing  Heading Accuracy  \
# 0  €560K        €138.4M        429        85         95                70
# 1  €220K         €75.9M        437        84         95                90
# 2  €125K        €159.4M         95        13         11                15
# 3  €370K          €161M        407        94         82                55
# 4  €270K        €166.5M        408        85         87                62
#
#    Short Passing  Volleys  Skill  Dribbling
# 0             91       88    470         96
# 1             82       86    414         88
# 2             43       13    109         12
# 3             94       82    441         88
# 4             87       87    448         95

# %% [markdown]
# # Working with anormalies

# %%
df3['Release Clause'].unique()
# Out:
# array(['€138.4M', '€75.9M', '€159.4M', ..., '€59K', '€35K', '€64K'],
#       dtype=object)

# %%
# release clause
#remove currency sign and value abbrev.

n_claus = []

for i in range(len(df3["Release Clause"])):
    c = df["Release Clause"][i]
    c = c.replace("€", "")
    c = c.replace("K","000")
    c = c.replace("M","000_000")
    c = c.replace(".","") 
    n_claus.append(int(c))
    
df3["Release Clause"] = n_claus

# %%
#Checking if the change is effective
df3['Release Clause'].unique()
# Out:
# array([1384000000,  759000000, 1594000000, ...,      59000,      35000,
#             64000], dtype=int64)

# %% [markdown]
# Wow! The change has been implemented

# %%
df3['Wage'].unique()
# Out:
# array(['€560K', '€220K', '€125K', '€370K', '€270K', '€240K', '€250K',
#        '€160K', '€260K', '€210K', '€310K', '€130K', '€350K', '€300K',
#        '€190K', '€145K', '€195K', '€100K', '€140K', '€290K', '€82K',
#        '€110K', '€230K', '€155K', '€200K', '€165K', '€95K', '€170K',
#        '€105K', '€115K', '€150K', '€135K', '€55K', '€58K', '€81K', '€34K',
#        '€120K', '€59K', '€90K', '€65K', '€56K', '€71K', '€18K', '€75K',
#        '€47K', '€20K', '€84K', '€86K', '€74K', '€78K', '€27K', '€68K',
#        '€85K', '€25K', '€46K', '€83K', '€54K', '€79K', '€175K', '€43K',
#        '€49K', '€45K', '€38K', '€41K', '€39K', '€23K', '€51K', '€50K',
#        '€87K', '€30K', '€14K', '€69K', '€31K', '€64K', '€53K', '€35K',
#        '€21K', '€28K', '€17K', '€33K', '€70K', '€32K', '€89K', '€26K',
#        '€40K', '€76K', '€72K', '€48K', '€36K', '€29K', '€60K', '€16K',
#        '€37K', '€24K', '€52K', '€0', '€62K', '€73K', '€63K', '€19K',
# ...

# %%
#Wage
#remove currency sign and value abbrev.

n_wage = []

for i in range(len(df3["Wage"])):
    w = df["Wage"][i]
    w = w.replace("€", "")
    w = w.replace("K","000")
    w = w.replace("M","000_000")
    w = w.replace(".","")     
    n_wage.append(int(w))
    
df3["Wage"] = n_wage

# %%
#Confirming if the change has beeen effective
df3['Wage'].unique()
# Out:
# array([560000, 220000, 125000, 370000, 270000, 240000, 250000, 160000,
#        260000, 210000, 310000, 130000, 350000, 300000, 190000, 145000,
#        195000, 100000, 140000, 290000,  82000, 110000, 230000, 155000,
#        200000, 165000,  95000, 170000, 105000, 115000, 150000, 135000,
#         55000,  58000,  81000,  34000, 120000,  59000,  90000,  65000,
#         56000,  71000,  18000,  75000,  47000,  20000,  84000,  86000,
#         74000,  78000,  27000,  68000,  85000,  25000,  46000,  83000,
#         54000,  79000, 175000,  43000,  49000,  45000,  38000,  41000,
#         39000,  23000,  51000,  50000,  87000,  30000,  14000,  69000,
#         31000,  64000,  53000,  35000,  21000,  28000,  17000,  33000,
#         70000,  32000,  89000,  26000,  40000,  76000,  72000,  48000,
#         36000,  29000,  60000,  16000,  37000,  24000,  52000,      0,
#         62000,  73000,  63000,  19000,   1000,  66000,  80000,  12000,
# ...

# %%
# boxplot of attacking column

df3.boxplot(column= 'Attacking')
plt.ylabel("Player's Attacking")
plt.title("Player's Attacking Boxplot")
plt.show()

# %%
# First quartile\
Q1 = df3['Attacking'].quantile(0.25)

# Second Quartile

Q3 = df3['Attacking'].quantile(0.75)

# interquartile range

IQR = Q3 - Q1

# IQR
IQR
# Out:
# 75.0

# %%
# whisker width

whisker_width = 1.5


# get the outlier records in dataset

Attacking_outliers = df3[(df3['Attacking'] < (Q1 - (whisker_width*IQR))) | (df3['Attacking'] > (Q3 + (whisker_width*IQR)))]


# records with Attacking outliers

Attacking_outliers['Attacking'].to_list()
# Out:
# [429,
#  437,
#  95,
#  423,
#  410,
#  86,
#  426,
#  411,
#  420,
#  86,
#  425,
#  78,
#  86,
#  429,
#  94,
#  419,
#  84,
#  78,
#  91,
#  94,
#  93,
#  90,
#  69,
#  105,
#  85,
#  93,
#  84,
#  98,
#  72,
#  92,
#  74,
#  417,
#  99,
#  88,
#  101,
#  100,
#  81,
#  87,
#  78,
#  55,
#  82,
#  88,
#  86,
#  95,
#  82,
#  105,
#  95,
#  91,
#  78,
#  81,
#  106,
#  78,
#  108,
#  91,
#  80,
#  75,
#  80,
#  97,
#  94,
#  55,
#  73,
#  94,
#  87,
#  85,
#  99,
#  103,
#  61,
#  103,
#  95,
#  98,
#  83,
#  43,
#  69,
#  43,
#  94,
#  101,
#  54,
#  92,
#  81,
#  70,
#  92,
#  103,
#  88,
#  100,
#  84,
#  97,
#  87,
#  93,
#  68,
#  75,
#  77,
#  95,
#  100,
#  91,
#  107,
#  78,
#  95,
#  98,
#  90,
#  89,
#  89,
#  72,
#  90,
#  90,
#  90,
#  89,
#  96,
#  109,
#  103,
#  100,
#  76,
#  95,
#  102,
#  86,
#  90,
#  68,
#  80,
#  95,
#  106,
#  89,
#  85,
#  74,
#  87,
#  93,
#  94,
#  90,
#  93,
#  95,
#  95,
#  70,
#  74,
#  104,
#  75,
#  66,
#  76,
#  72,
#  98,
#  63,
# ...

# %%
# list of Attacking outliers

Attacking_outliers['Attacking'].to_list()
# Out:
# [429,
#  437,
#  95,
#  423,
#  410,
#  86,
#  426,
#  411,
#  420,
#  86,
#  425,
#  78,
#  86,
#  429,
#  94,
#  419,
#  84,
#  78,
#  91,
#  94,
#  93,
#  90,
#  69,
#  105,
#  85,
#  93,
#  84,
#  98,
#  72,
#  92,
#  74,
#  417,
#  99,
#  88,
#  101,
#  100,
#  81,
#  87,
#  78,
#  55,
#  82,
#  88,
#  86,
#  95,
#  82,
#  105,
#  95,
#  91,
#  78,
#  81,
#  106,
#  78,
#  108,
#  91,
#  80,
#  75,
#  80,
#  97,
#  94,
#  55,
#  73,
#  94,
#  87,
#  85,
#  99,
#  103,
#  61,
#  103,
#  95,
#  98,
#  83,
#  43,
#  69,
#  43,
#  94,
#  101,
#  54,
#  92,
#  81,
#  70,
#  92,
#  103,
#  88,
#  100,
#  84,
#  97,
#  87,
#  93,
#  68,
#  75,
#  77,
#  95,
#  100,
#  91,
#  107,
#  78,
#  95,
#  98,
#  90,
#  89,
#  89,
#  72,
#  90,
#  90,
#  90,
#  89,
#  96,
#  109,
#  103,
#  100,
#  76,
#  95,
#  102,
#  86,
#  90,
#  68,
#  80,
#  95,
#  106,
#  89,
#  85,
#  74,
#  87,
#  93,
#  94,
#  90,
#  93,
#  95,
#  95,
#  70,
#  74,
#  104,
#  75,
#  66,
#  76,
#  72,
#  98,
#  63,
# ...

# %% [markdown]
# Let's Eliminate the outliers in the Attacking column

# %%
# whisker width
whisker_width = 1.5

# get the outlier records in dataset
Attacking_outliers = df3[(df3['Attacking'] < (Q1 - (whisker_width*IQR))) | (df3['Attacking'] > (Q3 + (whisker_width*IQR)))]

# drop the outliers
df3 = df3.drop(Attacking_outliers.index)

# show the updated boxplot without outliers
df3.boxplot(column='Attacking')
plt.ylabel("Player's Attacking")
plt.title("Player's Attacking Boxplot (without outliers)")
plt.show()

# %% [markdown]
# Great! The outliers have been eliminated successfully

# %%
df3['Attacking'].unique()
# Out:
# array([407, 408, 392, 114, 118, 316, 349, 119, 374, 360, 328, 383, 405,
#        123, 224, 388, 397, 373, 365, 371, 311, 396, 345, 399, 400, 280,
#        330, 403, 379, 380, 394, 339, 293, 344, 390, 359, 372, 377, 346,
#        389, 386, 308, 277, 382, 368, 402, 292, 298, 366, 352, 363, 322,
#        361, 364, 341, 385, 355, 305, 321, 262, 375, 387, 356, 253, 285,
#        391, 353, 367, 295, 378, 256, 338, 331, 358, 343, 319, 271, 113,
#        350, 406, 340, 393, 247, 334, 351, 342, 302, 329, 354, 301, 115,
#        384, 208, 376, 258, 362, 263, 279, 395, 310, 117, 409, 318, 323,
#        248, 315, 381, 348, 327, 309, 130, 283, 336, 369, 252, 320, 290,
#        370, 126, 251, 335, 297, 284, 357, 270, 306, 337, 286, 325, 326,
#        324, 333, 259, 273, 313, 296, 312, 347, 401, 304, 278, 314, 291,
#        264, 272, 317, 231, 250, 268, 261, 255, 281, 265, 299, 287, 294,
#        219, 300, 269, 332, 289, 288, 282, 122, 244, 112, 274, 276, 307,
# ...

# %%
df3.head()
# Out:
#      Wage  Release Clause  Attacking  Crossing  Finishing  Heading Accuracy  \
# 3  370000       161000000        407        94         82                55
# 4  270000      1665000000        408        85         87                62
# 6  250000      1443000000        392        79         91                59
# 7  160000      1203000000        114        17         13                19
# 8  160000      2031000000        408        78         91                73
#
#    Short Passing  Volleys  Skill  Dribbling
# 3             94       82    441         88
# 4             87       87    448         95
# 6             84       79    406         90
# 7             45       20    138         27
# 8             83       83    394         92

# %%
# boxplot of attacking column

df3.boxplot(column= 'Crossing')
plt.ylabel("Player's Crossing")
plt.title("Player's Crossing Boxplot")
plt.show()

# %%
# First quartile\
Q1 = df3['Crossing'].quantile(0.25)

# Second Quartile

Q3 = df3['Crossing'].quantile(0.75)

# interquartile range

IQR = Q3 - Q1

# IQR
IQR
# Out:
# 20.0

# %%
# whisker width

whisker_width = 1.5


# get the outlier records in dataset

Crossing_outliers = df3[(df3['Crossing'] < (Q1 - (whisker_width*IQR))) | (df3['Crossing'] > (Q3 + (whisker_width*IQR)))]


# records with Crossing outliers

Crossing_outliers['Crossing'].to_list()
# Out:
# [12, 12, 11, 12, 11, 12, 11, 13, 13, 13, 13]

# %% [markdown]
# There are some  outliers on the Crossing column lets eliminate them

# %%
# whisker width
whisker_width = 1.5

# get the outlier records in dataset
Crossing_outliers = df3[(df3['Crossing'] < (Q1 - (whisker_width*IQR))) | (df3['Crossing'] > (Q3 + (whisker_width*IQR)))]

# drop the outliers
df3 = df3.drop(Crossing_outliers.index)

# show the updated boxplot without outliers
df3.boxplot(column='Crossing')
plt.ylabel("Player's Crossing")
plt.title("Player's Crossing Boxplot (without outliers)")
plt.show()

# %% [markdown]
# Outliers eliminatedsuccessfully

# %% [markdown]
# Saving the dataset

# %%
# Save the dataset to a CSV file
df3.to_csv('df3_dataset.csv', index=False)

# %%
df.columns
# Out:
# Index(['ID', 'Name', 'LongName', 'photoUrl', 'playerUrl', 'Nationality', 'Age',
#        '↓OVA', 'POT', 'Club', 'Contract', 'Positions', 'Height', 'Weight',
#        'Preferred Foot', 'BOV', 'Best Position', 'Joined', 'Loan Date End',
#        'Value', 'Wage', 'Release Clause', 'Attacking', 'Crossing', 'Finishing',
#        'Heading Accuracy', 'Short Passing', 'Volleys', 'Skill', 'Dribbling',
#        'Curve', 'FK Accuracy', 'Long Passing', 'Ball Control', 'Movement',
#        'Acceleration', 'Sprint Speed', 'Agility', 'Reactions', 'Balance',
#        'Power', 'Shot Power', 'Jumping', 'Stamina', 'Strength', 'Long Shots',
#        'Mentality', 'Aggression', 'Interceptions', 'Positioning', 'Vision',
#        'Penalties', 'Composure', 'Defending', 'Marking', 'Standing Tackle',
#        'Sliding Tackle', 'Goalkeeping', 'GK Diving', 'GK Handling',
#        'GK Kicking', 'GK Positioning', 'GK Reflexes', 'Total Stats',
# ...

# %% [markdown]
# # Selecting columns for the fourth dataset

# %%
df4 = df[['Curve', 'FK Accuracy', 'Long Passing', 'Ball Control', 'Movement',
       'Acceleration', 'Sprint Speed', 'Agility', 'Reactions']]

# %%
df4.head()
# Out:
#    Curve  FK Accuracy  Long Passing  Ball Control  Movement  Acceleration  \
# 0     93           94            91            96       451            91
# 1     81           76            77            92       431            87
# 2     13           14            40            30       307            43
# 3     85           83            93            92       398            77
# 4     88           89            81            95       453            94
#
#    Sprint Speed  Agility  Reactions
# 0            80       91         94
# 1            91       87         95
# 2            60       67         88
# 3            76       78         91
# 4            89       96         91

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18979 entries, 0 to 18978
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Curve         18979 non-null  int64
#  1   FK Accuracy   18979 non-null  int64
#  2   Long Passing  18979 non-null  int64
#  3   Ball Control  18979 non-null  int64
#  4   Movement      18979 non-null  int64
#  5   Acceleration  18979 non-null  int64
#  6   Sprint Speed  18979 non-null  int64
#  7   Agility       18979 non-null  int64
#  8   Reactions     18979 non-null  int64
# dtypes: int64(9)
# memory usage: 1.3 MB

# %%
df4.dtypes
# Out:
# Curve           int64
# FK Accuracy     int64
# Long Passing    int64
# Ball Control    int64
# Movement        int64
# Acceleration    int64
# Sprint Speed    int64
# Agility         int64
# Reactions       int64
# dtype: object

# %%
df4.describe()
# Out:
#               Curve   FK Accuracy  Long Passing  Ball Control      Movement  \
# count  18979.000000  18979.000000  18979.000000  18979.000000  18979.000000
# mean      47.246957     42.391011     52.725381     58.528373    317.718689
# std       18.207790     17.227947     15.178151     16.565892     55.879046
# min        4.000000      5.000000      5.000000      5.000000    122.000000
# 25%       35.000000     31.000000     43.000000     54.000000    289.000000
# 50%       49.000000     41.000000     56.000000     63.000000    327.000000
# 75%       61.000000     55.000000     64.000000     69.000000    356.000000
# max       94.000000     94.000000     93.000000     96.000000    464.000000
#
#        Acceleration  Sprint Speed       Agility     Reactions
# count  18979.000000  18979.000000  18979.000000  18979.000000
# mean      64.357553     64.412930     63.366721     61.655619
# std       14.889981     14.638743     14.596277      9.072114
# ...

# %%
df4.isna().sum()
# Out:
# Curve           0
# FK Accuracy     0
# Long Passing    0
# Ball Control    0
# Movement        0
# Acceleration    0
# Sprint Speed    0
# Agility         0
# Reactions       0
# dtype: int64

# %% [markdown]
# Great! There are no missing values in the df4 set of the dataset

# %%
df4.duplicated().sum()
# Out:
# 9

# %% [markdown]
# There are nine duplicate values in the df4 dataset lets work 0on them now

# %%
# remove duplicates based on all columns
df4 = df4.drop_duplicates()

# %% [markdown]
# Lets confirm if the duplicates have been removed

# %%
df4.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Great! The duplicates have beed dealt with successfully

# %% [markdown]
# # Working on the unique values in our columns

# %%
df4['Curve'].unique()
# Out:
# array([93, 81, 13, 85, 88, 79, 83, 19, 18, 60, 76, 63, 14, 74, 77, 49, 15,
#        80, 12, 28, 86, 84, 82, 61, 71, 11, 66, 16, 89, 70, 21, 46, 78, 67,
#        58, 65, 48, 34, 90, 59, 55, 87, 62,  9, 56, 36, 30, 32, 73, 69, 68,
#        75, 45, 10, 72, 64, 41, 23, 47, 20, 51, 25, 44, 17, 54, 57, 53, 33,
#        40, 50, 39, 35, 52, 42, 37, 43, 26, 31, 92, 91, 29, 94, 27, 38, 22,
#        24,  8,  6,  7,  5,  4], dtype=int64)

# %%
df4['FK Accuracy'].unique()
# Out:
# array([94, 76, 14, 83, 89, 85, 69, 18, 63, 12, 70, 64, 74, 20, 11, 73, 49,
#        61, 88, 68, 28, 79, 84, 48, 67, 38, 87, 53, 65, 15, 31, 78, 82, 10,
#        51, 59, 19, 47, 52, 57, 43, 13, 77, 54, 75, 86, 55, 30, 62, 32, 58,
#        93,  8, 66, 71, 81, 92, 44, 17, 60, 40, 16, 72, 46, 35, 45, 29, 21,
#        56, 80, 24, 22, 39, 42, 26, 41,  9, 37, 27, 50, 33, 25, 36, 91, 34,
#        23,  7,  6, 90,  5], dtype=int64)

# %%
df4['Long Passing'].unique()
# Out:
# array([91, 77, 40, 93, 81, 70, 75, 44, 63, 86, 71, 84, 35, 59, 73, 83, 64,
#        69, 79, 82, 68, 89, 76, 80, 87, 37, 65, 36, 50, 53, 78, 47, 74, 48,
#        31, 85, 24, 55, 90, 54, 62, 32, 49, 66, 67, 51, 28, 46, 52, 72, 56,
#        41, 45, 22, 88, 61, 33, 12, 60, 17, 27, 29, 23, 38, 16, 58, 34, 25,
#        39, 21, 30, 42, 43, 57, 20, 26, 18, 19, 13, 15, 11, 14,  9, 10,  5,
#         8], dtype=int64)

# %%
df4['Ball Control'].unique()
# Out:
# array([96, 92, 30, 95, 88, 89, 90, 77, 79, 23, 46, 83, 80, 85, 94, 40, 84,
#        16, 74, 91, 87, 82, 78, 19, 61, 22, 34, 38, 81, 25, 86, 76, 69, 28,
#        93, 75, 35, 60, 63, 73, 18, 71, 15, 21, 72, 14, 65, 20, 24, 27, 70,
#        33, 17, 62, 64,  9, 68, 67, 32, 26, 66, 52, 11, 57, 58, 29, 12, 37,
#        10, 36, 13, 31, 55, 59, 39, 54, 56, 48, 44, 51, 50, 47, 49, 53,  5,
#        42,  8, 45, 43, 41,  7], dtype=int64)

# %%
df4['Movement'].unique()
# Out:
# array([451, 431, 307, 398, 453, 407, 460, 268, 458, 254, 354, 343, 284,
#        286, 388, 378, 424, 464, 420, 399, 437, 322, 367, 272, 328, 448,
#        332, 425, 435, 391, 434, 400, 331, 349, 429, 416, 312, 326, 418,
#        419, 417, 386, 321, 409, 374, 304, 403, 351, 401, 365, 414, 292,
#        323, 299, 433, 350, 348, 413, 320, 281, 427, 353, 364, 410, 428,
#        316, 381, 442, 375, 288, 395, 385, 251, 319, 444, 383, 298, 411,
#        412, 415, 393, 397, 443, 423, 387, 422, 327, 390, 362, 352, 406,
#        277, 361, 421, 396, 384, 450, 338, 363, 359, 287, 297, 430, 382,
#        377, 380, 438, 449, 257, 371, 339, 341, 404, 345, 394, 295, 246,
#        265, 258, 366, 294, 314, 266, 405, 218, 337, 267, 220, 376, 309,
#        283, 426, 347, 244, 240, 291, 340, 250, 305, 290, 317, 334, 355,
#        333, 389, 330, 318, 441, 402, 344, 335, 219, 264, 408, 274, 373,
#        379, 256, 229, 392, 372, 360, 262, 346, 278, 248, 368, 279, 269,
# ...

# %%
df4['Acceleration'].unique()
# Out:
# array([91, 87, 43, 77, 94, 56, 96, 38, 72, 95, 60, 42, 54, 79, 89, 64, 66,
#        51, 73, 57, 80, 86, 85, 78, 40, 82, 76, 65, 68, 90, 48, 46, 88, 70,
#        83, 84, 93, 52, 74, 92, 55, 58, 59, 67, 81, 62, 44, 71, 69, 50, 53,
#        45, 49, 75, 41, 61, 63, 35, 47, 34, 36, 37, 39, 30, 97, 31, 33, 32,
#        27, 28, 26, 29, 25, 17, 19, 24, 15, 23, 21, 20, 22, 16, 18, 13, 14],
#       dtype=int64)

# %%
df4['Sprint Speed'].unique()
# Out:
# array([80, 91, 60, 76, 89, 78, 92, 47, 96, 50, 79, 93, 69, 52, 72, 70, 90,
#        66, 82, 63, 55, 77, 86, 81, 83, 85, 65, 68, 53, 43, 94, 62, 58, 61,
#        87, 64, 67, 54, 88, 75, 95, 73, 49, 84, 56, 44, 74, 51, 57, 46, 59,
#        71, 37, 34, 33, 42, 30, 35, 48, 39, 45, 40, 18, 38, 41, 27, 32, 29,
#        28, 36, 26, 31, 22, 25, 23, 15, 20, 17, 16, 24, 19, 21, 12, 14],
#       dtype=int64)

# %%
df4['Agility'].unique()
# Out:
# array([91, 87, 67, 78, 96, 77, 40, 92, 37, 61, 93, 51, 79, 84, 94, 82, 60,
#        69, 47, 52, 63, 74, 59, 66, 86, 85, 57, 55, 76, 75, 73, 62, 72, 90,
#        68, 64, 80, 56, 48, 83, 41, 81, 54, 88, 33, 65, 49, 71, 89, 45, 70,
#        43, 50, 32, 42, 39, 58, 36, 34, 53, 46, 95, 44, 38, 21, 29, 35, 31,
#        19, 26, 30, 22, 28, 24, 25, 23, 27, 14, 18, 15, 20], dtype=int64)

# %%
df4['Reactions'].unique()
# Out:
# array([94, 95, 88, 91, 93, 92, 86, 89, 87, 84, 90, 83, 85, 82, 81, 79, 80,
#        74, 75, 78, 77, 73, 76, 71, 70, 68, 72, 66, 69, 65, 67, 64, 59, 60,
#        62, 63, 61, 58, 57, 56, 50, 54, 53, 55, 52, 32, 49, 48, 45, 51, 46,
#        47, 37, 34, 44, 40, 38, 43, 41, 35, 42, 33, 39, 31, 36, 30, 24, 29,
#        28], dtype=int64)

# %% [markdown]
# # working on annormalies in the df4 dataset

# %%
# boxplot of Reaction column

df4.boxplot(column= 'Reactions')
plt.ylabel("Player's Reactions")
plt.title("Player's Reactions Boxplot")
plt.show()

# %%
# First quartile\
Q1 = df4['Reactions'].quantile(0.25)

# Second Quartile

Q3 = df4['Reactions'].quantile(0.75)

# interquartile range

IQR = Q3 - Q1

# IQR
IQR
# Out:
# 12.0

# %%
# whisker width

whisker_width = 1.5


# get the outlier records in dataset

Reactions_outliers = df4[(df4['Reactions'] < (Q1 - (whisker_width*IQR))) | (df4['Reactions'] > (Q3 + (whisker_width*IQR)))]


# records with Reactions outliers

Reactions_outliers['Reactions'].to_list()
# Out:
# [94,
#  95,
#  88,
#  91,
#  91,
#  93,
#  92,
#  88,
#  92,
#  89,
#  93,
#  87,
#  91,
#  92,
#  92,
#  90,
#  91,
#  88,
#  87,
#  90,
#  89,
#  92,
#  87,
#  87,
#  89,
#  90,
#  88,
#  88,
#  92,
#  90,
#  94,
#  87,
#  90,
#  88,
#  87,
#  87,
#  87,
#  88,
#  88,
#  87,
#  87,
#  88,
#  88,
#  88,
#  87,
#  87,
#  88,
#  32,
#  37,
#  34,
#  35,
#  35,
#  33,
#  37,
#  37,
#  32,
#  31,
#  36,
#  36,
#  33,
#  31,
#  35,
#  37,
#  31,
#  32,
#  37,
#  37,
#  30,
#  37,
#  37,
#  34,
#  37,
#  34,
#  36,
#  35,
#  32,
#  35,
#  32,
#  36,
#  24,
#  35,
#  36,
#  33,
#  36,
#  33,
#  37,
#  31,
#  34,
#  35,
#  37,
#  35,
#  36,
#  35,
#  37,
#  31,
#  36,
#  37,
#  35,
#  35,
#  31,
#  33,
#  37,
#  30,
#  35,
#  36,
#  34,
#  34,
#  35,
#  32,
#  36,
#  36,
#  37,
#  32,
#  31,
#  30,
#  35,
#  37,
#  36,
#  36,
#  35,
#  37,
#  37,
#  32,
#  30,
#  32,
#  37,
#  37,
#  36,
#  32,
#  33,
#  35,
#  35,
#  35,
#  37,
#  35,
#  37,
#  37,
#  37,
#  33,
#  33,
#  36,
#  35,
# ...

# %% [markdown]
# From the above analysis any value above 87 and below 39 is being regarded as an outlier

# %% [markdown]
# Let's work on the outliers by removing them

# %%
# whisker width
whisker_width = 1.5

# get the outlier records in dataset
Reactions_outliers = df4[(df4['Reactions'] < (Q1 - (whisker_width*IQR))) | (df4['Reactions'] > (Q3 + (whisker_width*IQR)))]

# drop the outliers
df4 = df4.drop(Reactions_outliers.index)

# show the updated boxplot without outliers
df4.boxplot(column='Reactions')
plt.ylabel("Player's Reactions")
plt.title("Player's Reactions Boxplot (without outliers)")
plt.show()

# %% [markdown]
# Wow! The outliers have beeen eliminated successfully

# %%
# whisker width
whisker_width = 1.5

# get the outlier records in dataset
Reactions_outliers = df4[(df4['Reactions'] < (Q1 - (whisker_width*IQR))) | (df4['Reactions'] > (Q3 + (whisker_width*IQR)))]

# drop the outliers
df4 = df4.drop(Reactions_outliers.index)

# show the updated boxplot without outliers
df4.boxplot(column='Reactions')
plt.ylabel("Player's Reactions")
plt.title("Player's Reactions Boxplot (without outliers)")
plt.show()

# %%
# boxplot of Reaction column

df4.boxplot(column= 'Agility')
plt.ylabel("Player's Agility")
plt.title("Player's Agility Boxplot")
plt.show()

# %%
# First quartile\
Q1 = df4['Agility'].quantile(0.25)

# Second Quartile

Q3 = df4['Agility'].quantile(0.75)

# interquartile range

IQR = Q3 - Q1

# IQR
IQR
# Out:
# 18.0

# %%
# whisker width

whisker_width = 1.5


# get the outlier records in dataset

Agility_outliers = df4[(df4['Agility'] < (Q1 - (whisker_width*IQR))) | (df4['Agility'] > (Q3 + (whisker_width*IQR)))]


# records with Agility outliers

Agility_outliers['Agility'].to_list()
# Out:
# [21,
#  19,
#  26,
#  26,
#  21,
#  22,
#  28,
#  24,
#  22,
#  28,
#  21,
#  22,
#  28,
#  28,
#  25,
#  25,
#  22,
#  28,
#  21,
#  21,
#  22,
#  23,
#  27,
#  21,
#  26,
#  21,
#  23,
#  24,
#  23,
#  14,
#  26,
#  28,
#  22,
#  27,
#  28,
#  28,
#  23,
#  27,
#  24,
#  22,
#  27,
#  25,
#  26,
#  22,
#  21,
#  27,
#  24,
#  24,
#  23,
#  25,
#  22,
#  27,
#  24,
#  27,
#  26,
#  27,
#  27,
#  23,
#  19,
#  25,
#  28,
#  24,
#  26,
#  25,
#  25,
#  23,
#  28,
#  27,
#  23,
#  21,
#  26,
#  22,
#  22,
#  25,
#  28,
#  28,
#  24,
#  28,
#  28,
#  25,
#  22,
#  21,
#  22,
#  27,
#  23,
#  28,
#  24,
#  24,
#  26,
#  26,
#  25,
#  28,
#  26,
#  26,
#  23,
#  25,
#  27,
#  27,
#  23,
#  27,
#  22,
#  25,
#  23,
#  24,
#  25,
#  26,
#  21,
#  26,
#  23,
#  24,
#  23,
#  27,
#  26,
#  27,
#  24,
#  24,
#  18,
#  28,
#  22,
#  26,
#  26,
#  26,
#  28,
#  25,
#  26,
#  26,
#  28,
#  28,
#  23,
#  23,
#  28,
#  27,
#  23,
#  25,
#  27,
#  28,
#  22,
#  21,
#  22,
#  23,
#  28,
#  25,
# ...

# %% [markdown]
# From the above analysis, all the outliers are the Agility values below 27

# %% [markdown]
# Let's work on eliminating the outliers

# %%
# whisker width
whisker_width = 1.5

# get the outlier records in dataset
Agility_outliers = df4[(df4['Agility'] < (Q1 - (whisker_width*IQR))) | (df4['Agility'] > (Q3 + (whisker_width*IQR)))]

# drop the outliers
df4 = df4.drop(Agility_outliers.index)

# show the updated boxplot without outliers
df4.boxplot(column='Agility')
plt.ylabel("Player's Agility")
plt.title("Player's Agility Boxplot (without outliers)")
plt.show()

# %% [markdown]
# Great! the outliers eliminated successfully

# %%
# boxplot of Sprint Speed column

df4.boxplot(column= 'Sprint Speed')
plt.ylabel("Player's sprint speed")
plt.title("Player's sprint speed Boxplot")
plt.show()

# %%
# First quartile\
Q1 = df4['Sprint Speed'].quantile(0.25)

# Second Quartile

Q3 = df4['Sprint Speed'].quantile(0.75)

# interquartile range

IQR = Q3 - Q1

# IQR
IQR
# Out:
# 16.0

# %%
# whisker width

whisker_width = 1.5


# get the outlier records in dataset

Sprint_Speed_outliers = df4[(df4['Sprint Speed'] < (Q1 - (whisker_width*IQR))) | (df4['Sprint Speed'] > (Q3 + (whisker_width*IQR)))]


# records with Sprint Speed outliers

Sprint_Speed_outliers['Sprint Speed'].to_list()
# Out:
# [33,
#  30,
#  18,
#  33,
#  30,
#  32,
#  29,
#  33,
#  32,
#  33,
#  28,
#  33,
#  33,
#  26,
#  29,
#  32,
#  32,
#  31,
#  33,
#  31,
#  32,
#  26,
#  33,
#  33,
#  33,
#  30,
#  30,
#  33,
#  18,
#  32,
#  32,
#  27,
#  28,
#  33,
#  32,
#  22,
#  25,
#  32,
#  31,
#  15,
#  27,
#  32,
#  27,
#  31,
#  32,
#  32,
#  31,
#  33,
#  32,
#  31,
#  32,
#  32,
#  32,
#  33,
#  33,
#  31,
#  33,
#  32,
#  33,
#  32,
#  32,
#  32,
#  33,
#  26,
#  32,
#  30,
#  32,
#  32,
#  33,
#  28,
#  28,
#  33,
#  31,
#  33,
#  33,
#  24,
#  25,
#  30,
#  32,
#  31,
#  18,
#  15,
#  28,
#  32,
#  30,
#  33,
#  33,
#  32,
#  32,
#  15,
#  29,
#  25,
#  29,
#  30,
#  30,
#  33,
#  28,
#  32,
#  31,
#  28,
#  33,
#  33,
#  31,
#  33,
#  30,
#  32,
#  31,
#  30,
#  23,
#  32,
#  33,
#  33,
#  28,
#  31,
#  33,
#  30,
#  33,
#  30,
#  30,
#  29,
#  26,
#  33,
#  33,
#  30,
#  23,
#  30,
#  33,
#  32,
#  33,
#  33,
#  33,
#  33,
#  33,
#  32,
#  30,
#  31,
#  32,
#  30,
#  31,
#  32,
#  26,
#  33,
# ...

# %% [markdown]
# From the above analysis the outliers are the sprint speed  values that are below 32

# %% [markdown]
# Eliminating the outliers

# %%
# whisker width
whisker_width = 1.5

# get the outlier records in dataset
Sprint_Speed_outliers = df4[(df4['Sprint Speed'] < (Q1 - (whisker_width*IQR))) | (df4['Sprint Speed'] > (Q3 + (whisker_width*IQR)))]

# drop the outliers
df4 = df4.drop(Sprint_Speed_outliers.index)

# show the updated boxplot without outliers
df4.boxplot(column='Sprint Speed')
plt.ylabel("Player's Sprint Speed")
plt.title("Player's Sprint Speed Boxplot (without outliers)")
plt.show()

# %%
# boxplot of Sprint Speed column

df4.boxplot(column= 'Acceleration')
plt.ylabel("Player's Acceleration")
plt.title("Player's Acceleration Boxplot")
plt.show()

# %%
# First quartile\
Q1 = df4['Acceleration'].quantile(0.25)

# Second Quartile

Q3 = df4['Acceleration'].quantile(0.75)

# interquartile range

IQR = Q3 - Q1

# IQR
IQR
# Out:
# 15.0

# %%
# whisker width

whisker_width = 1.5


# get the outlier records in dataset

Acceleration_outliers = df4[(df4['Acceleration'] < (Q1 - (whisker_width*IQR))) | (df4['Acceleration'] > (Q3 + (whisker_width*IQR)))]


# records with Acceleration outliers

Acceleration_outliers['Acceleration'].to_list()
# Out:
# [35,
#  36,
#  34,
#  36,
#  37,
#  34,
#  35,
#  34,
#  31,
#  37,
#  33,
#  35,
#  37,
#  35,
#  35,
#  34,
#  32,
#  34,
#  37,
#  34,
#  37,
#  26,
#  34,
#  33,
#  37,
#  32,
#  28,
#  37,
#  32,
#  34,
#  32,
#  34,
#  36,
#  34,
#  35,
#  29,
#  37,
#  35,
#  33,
#  35,
#  33,
#  32,
#  25,
#  34,
#  33,
#  32,
#  31,
#  33,
#  37,
#  34,
#  33,
#  35,
#  34,
#  35,
#  33,
#  35,
#  34,
#  35,
#  37,
#  29,
#  37,
#  36,
#  37,
#  35,
#  29,
#  36,
#  31,
#  37,
#  29,
#  34,
#  34,
#  32,
#  31,
#  30,
#  35,
#  37,
#  33,
#  32,
#  34,
#  33,
#  34,
#  28,
#  37,
#  36,
#  33,
#  36,
#  30,
#  34,
#  33,
#  35,
#  35,
#  32,
#  33,
#  35,
#  33,
#  32,
#  35,
#  33,
#  32,
#  35,
#  36,
#  34,
#  33,
#  35,
#  35,
#  34,
#  35,
#  32,
#  37,
#  34,
#  34,
#  32,
#  33,
#  32,
#  33,
#  31,
#  33,
#  32,
#  34,
#  37,
#  36,
#  34,
#  36,
#  36,
#  30,
#  29,
#  37,
#  32,
#  29,
#  34,
#  32,
#  36,
#  36,
#  36,
#  37,
#  33,
#  33,
#  34,
#  34,
#  35,
#  34,
#  34,
# ...

# %% [markdown]
# From the above analysis the outliers are on the Acceleration values below 32

# %% [markdown]
# Eliminating the outliers

# %%
# whisker width
whisker_width = 1.5

# get the outlier records in dataset
Acceleration_outliers = df4[(df4['Acceleration'] < (Q1 - (whisker_width*IQR))) | (df4['Acceleration'] > (Q3 + (whisker_width*IQR)))]

# drop the outliers
df4 = df4.drop(Acceleration_outliers.index)

# show the updated boxplot without outliers
df4.boxplot(column='Acceleration')
plt.ylabel("Player's Acceleration")
plt.title("Player's Acceleration Boxplot (without outliers)")
plt.show()

# %%
# boxplot of Sprint Speed column

df4.boxplot(column= 'Movement')
plt.ylabel("Player's Movement")
plt.title("Player's Movement Boxplot")
plt.show()

# %%
# First quartile\
Q1 = df4['Movement'].quantile(0.25)

# Second Quartile

Q3 = df4['Movement'].quantile(0.75)

# interquartile range

IQR = Q3 - Q1

# IQR
IQR
# Out:
# 59.0

# %%
# whisker width

whisker_width = 1.5


# get the outlier records in dataset

Movement_outliers = df4[(df4['Movement'] < (Q1 - (whisker_width*IQR))) | (df4['Acceleration'] > (Q3 + (whisker_width*IQR)))]


# records with Movement outliers

Movement_outliers['Movement'].to_list()
# Out:
# [209,
#  207,
#  205,
#  211,
#  210,
#  190,
#  211,
#  205,
#  208,
#  198,
#  209,
#  210,
#  209,
#  211,
#  204,
#  211,
#  201,
#  191,
#  207,
#  206,
#  208,
#  204,
#  208,
#  206,
#  205,
#  209,
#  211,
#  204,
#  210,
#  202,
#  208,
#  210,
#  209,
#  210,
#  191,
#  210,
#  209,
#  195,
#  205,
#  210,
#  207,
#  210,
#  190,
#  211,
#  210,
#  210,
#  207,
#  211,
#  208,
#  205,
#  207,
#  210,
#  191,
#  206,
#  207,
#  208,
#  201,
#  191,
#  201,
#  200,
#  202,
#  205,
#  205,
#  174,
#  208,
#  198,
#  197]

# %% [markdown]
# From the above analysis, the outliers are the Movement values above 450 and below 200

# %% [markdown]
# Eliminating the outliers

# %%
# whisker width
whisker_width = 1.5

# get the outlier records in dataset
Movement_outliers = df4[(df4['Movement'] < (Q1 - (whisker_width*IQR))) | (df4['Movement'] > (Q3 + (whisker_width*IQR)))]

# drop the outliers
df4 = df4.drop(Movement_outliers.index)

# show the updated boxplot without outliers
df4.boxplot(column='Movement')
plt.ylabel("Player's Movement")
plt.title("Player's Movement Boxplot (without outliers)")
plt.show()

# %% [markdown]
# Great! Outliers eliminated successfully

# %%
# boxplot of Reaction column

df4.boxplot(column= 'Ball Control')
plt.ylabel("Player's Ball control")
plt.title("Player's Ball Control Boxplot")
plt.show()

# %%
# First quartile\
Q1 = df4['Ball Control'].quantile(0.25)

# Second Quartile

Q3 = df4['Ball Control'].quantile(0.75)

# interquartile range

IQR = Q3 - Q1

# IQR
IQR
# Out:
# 12.0

# %%
# whisker width

whisker_width = 1.5


# get the outlier records in dataset

Ball_Control_outliers = df4[(df4['Ball Control'] < (Q1 - (whisker_width*IQR))) | (df4['Acceleration'] > (Q3 + (whisker_width*IQR)))]


# records with Ball Control​ outliers

Ball_Control_outliers['Ball Control'].to_list()
# Out:
# [30,
#  23,
#  94,
#  16,
#  19,
#  22,
#  34,
#  38,
#  25,
#  84,
#  85,
#  28,
#  83,
#  85,
#  93,
#  35,
#  79,
#  25,
#  89,
#  38,
#  87,
#  87,
#  23,
#  86,
#  18,
#  25,
#  83,
#  83,
#  78,
#  84,
#  83,
#  85,
#  16,
#  35,
#  15,
#  83,
#  83,
#  81,
#  81,
#  21,
#  14,
#  86,
#  20,
#  23,
#  24,
#  27,
#  81,
#  19,
#  82,
#  24,
#  15,
#  15,
#  21,
#  24,
#  82,
#  22,
#  24,
#  23,
#  20,
#  84,
#  17,
#  14,
#  27,
#  81,
#  80,
#  79,
#  80,
#  79,
#  72,
#  83,
#  9,
#  81,
#  76,
#  14,
#  23,
#  25,
#  21,
#  84,
#  32,
#  26,
#  85,
#  84,
#  85,
#  15,
#  22,
#  23,
#  23,
#  85,
#  28,
#  21,
#  78,
#  32,
#  16,
#  76,
#  80,
#  23,
#  83,
#  20,
#  84,
#  80,
#  20,
#  35,
#  74,
#  23,
#  84,
#  75,
#  24,
#  15,
#  24,
#  22,
#  20,
#  74,
#  80,
#  80,
#  81,
#  74,
#  81,
#  76,
#  83,
#  20,
#  24,
#  22,
#  78,
#  76,
#  32,
#  81,
#  22,
#  29,
#  74,
#  25,
#  12,
#  18,
#  23,
#  81,
#  84,
#  21,
#  37,
#  78,
#  10,
#  80,
#  77,
#  79,
#  77,
# ...

# %% [markdown]
# From the above analysis the outliers are the values above 87 and below 10

# %% [markdown]
# Eliminating the outliers

# %%
# whisker width
whisker_width = 1.5

# get the outlier records in dataset
Ball_Control_outliers = df4[(df4['Ball Control'] < (Q1 - (whisker_width*IQR))) | (df4['Ball Control'] > (Q3 + (whisker_width*IQR)))]

# drop the outliers
df4 = df4.drop(Ball_Control_outliers.index)

# show the updated boxplot without outliers
df4.boxplot(column='Ball Control')
plt.ylabel("Player's Ball Control")
plt.title("Player's Ball Control Boxplot (without outliers)")
plt.show()

# %% [markdown]
# Outliers eliminated successfully

# %%
# boxplot of Reaction column

df4.boxplot(column= 'Long Passing')
plt.ylabel("Player's Long Passing")
plt.title("Player's Long Passing Boxplot")
plt.show()

# %%
# First quartile\
Q1 = df4['Long Passing'].quantile(0.25)

# Second Quartile

Q3 = df4['Long Passing'].quantile(0.75)

# interquartile range

IQR = Q3 - Q1

# IQR
IQR
# Out:
# 16.0

# %%
# whisker width

whisker_width = 1.5


# get the outlier records in dataset

Long_Passing_outliers = df4[(df4['Long Passing'] < (Q1 - (whisker_width*IQR))) | (df4['Long Passing'] > (Q3 + (whisker_width*IQR)))]


# records with Long_Passing outliers

Long_Passing_outliers['Long Passing'].to_list()
# Out:
# [90,
#  21,
#  22,
#  23,
#  23,
#  22,
#  24,
#  24,
#  24,
#  24,
#  24,
#  24,
#  24,
#  20,
#  24,
#  23,
#  24,
#  22,
#  23,
#  22,
#  21,
#  23,
#  22,
#  21,
#  21,
#  23,
#  20,
#  23,
#  23,
#  21,
#  23,
#  21,
#  24,
#  22,
#  20,
#  23,
#  24,
#  22,
#  21,
#  24,
#  23,
#  23,
#  21,
#  23,
#  22,
#  19,
#  23,
#  24,
#  24,
#  22,
#  21,
#  23,
#  22,
#  24,
#  20,
#  24,
#  22,
#  22,
#  22,
#  20,
#  22,
#  23,
#  23,
#  22,
#  24,
#  22,
#  22,
#  23,
#  24,
#  21,
#  23,
#  23,
#  22,
#  24,
#  21,
#  23,
#  23,
#  22,
#  23,
#  20,
#  23,
#  23,
#  21,
#  21,
#  22,
#  23]

# %% [markdown]
# From the above analysis the outliers are the values below 12

# %% [markdown]
# Eliminating the outliers

# %%
# whisker width
whisker_width = 1.5

# get the outlier records in dataset
Long_Passing_outliers = df4[(df4['Long Passing'] < (Q1 - (whisker_width*IQR))) | (df4['Long Passing'] > (Q3 + (whisker_width*IQR)))]

# drop the outliers
df4 = df4.drop(Long_Passing_outliers.index)

# show the updated boxplot without outliers
df4.boxplot(column='Long Passing')
plt.ylabel("Player's Long Passing")
plt.title("Player's Long Passing Boxplot (without outliers)")
plt.show()

# %% [markdown]
# Great! The outliers have been eliminated successfully

# %%
# boxplot of Reaction column

df4.boxplot(column= 'FK Accuracy')
plt.ylabel("Player's FK Accuracy")
plt.title("Player'sFK AccuracyBoxplot")
plt.show()

# %%
# First quartile\
Q1 = df4['FK Accuracy'].quantile(0.25)

# Second Quartile

Q3 = df4['FK Accuracy'].quantile(0.75)

# interquartile range

IQR = Q3 - Q1

# IQR
IQR
# Out:
# 23.0

# %%
# whisker width

whisker_width = 1.5


# get the outlier records in dataset

FK_Accuracy_outliers = df4[(df4['FK Accuracy'] < (Q1 - (whisker_width*IQR))) | (df4['FK Accuracy'] > (Q3 + (whisker_width*IQR)))]


# records with FK_Accuracy outliers

FK_Accuracy_outliers['FK Accuracy'].to_list()
# Out:
# []

# %% [markdown]
# From the above analysis The FK Accuracy column has only Three outliers. that is 92, 93, 94

# %% [markdown]
# Eliminating the outliers

# %%
# whisker width
whisker_width = 1.5

# get the outlier records FK Accuracyin dataset
FK_Accuracy_outliers = df4[(df4['FK Accuracy'] < (Q1 - (whisker_width*IQR))) | (df4['FK Accuracy'] > (Q3 + (whisker_width*IQR)))]

# drop the outliers
df4 = df4.drop(FK_Accuracy_outliers.index)

# show the updated boxplot without outliers
df4.boxplot(column='FK Accuracy')
plt.ylabel("Player's FK Accuracy")
plt.title("Player's FK Accuracy Boxplot (without outliers)")
plt.show()

# %% [markdown]
# Great! The outliers are successfully eliminated

# %%
# boxplot of Reaction column

df4.boxplot(column= 'Curve')
plt.ylabel("Player's Curve")
plt.title("Player's Curve Boxplot")
plt.show()

# %%
# First quartile\
Q1 = df4['Curve'].quantile(0.25)

# Second Quartile

Q3 = df4['Curve'].quantile(0.75)

# interquartile range

IQR = Q3 - Q1

# IQR
IQR
# Out:
# 22.0

# %%
# whisker width

whisker_width = 1.5


# get the outlier records in dataset

Curve_outliers = df4[(df4['Curve'] < (Q1 - (whisker_width*IQR))) | (df4['Curve'] > (Q3 + (whisker_width*IQR)))]


# records with Curve outliers

Curve_outliers['Curve'].to_list()
# Out:
# []

# %% [markdown]
# Awsome! The cuyrve column has no outliers

# %% [markdown]
# Saving the dataset to a csv

# %%
# Save the dataset to a CSV file
df4.to_csv('df4_dataset.csv', index=False)

# %% [markdown]
# # Selecting more columns for the df5 dataset

# %%
df.columns
# Out:
# Index(['ID', 'Name', 'LongName', 'photoUrl', 'playerUrl', 'Nationality', 'Age',
#        '↓OVA', 'POT', 'Club', 'Contract', 'Positions', 'Height', 'Weight',
#        'Preferred Foot', 'BOV', 'Best Position', 'Joined', 'Loan Date End',
#        'Value', 'Wage', 'Release Clause', 'Attacking', 'Crossing', 'Finishing',
#        'Heading Accuracy', 'Short Passing', 'Volleys', 'Skill', 'Dribbling',
#        'Curve', 'FK Accuracy', 'Long Passing', 'Ball Control', 'Movement',
#        'Acceleration', 'Sprint Speed', 'Agility', 'Reactions', 'Balance',
#        'Power', 'Shot Power', 'Jumping', 'Stamina', 'Strength', 'Long Shots',
#        'Mentality', 'Aggression', 'Interceptions', 'Positioning', 'Vision',
#        'Penalties', 'Composure', 'Defending', 'Marking', 'Standing Tackle',
#        'Sliding Tackle', 'Goalkeeping', 'GK Diving', 'GK Handling',
#        'GK Kicking', 'GK Positioning', 'GK Reflexes', 'Total Stats',
# ...

# %%
df5 = df[['Balance','Power', 'Shot Power', 'Jumping', 'Stamina', 'Strength', 'Long Shots',
       'Mentality', 'Aggression', 'Interceptions']]

# %%
df5.head()
# Out:
#    Balance  Power  Shot Power  Jumping  Stamina  Strength  Long Shots  \
# 0       95    389          86       68       72        69          94
# 1       71    444          94       95       84        78          93
# 2       49    268          59       78       41        78          12
# 3       76    408          91       63       89        74          91
# 4       83    357          80       62       81        50          84
#
#    Mentality  Aggression  Interceptions
# 0        347          44             40
# 1        353          63             29
# 2        140          34             19
# 3        408          76             66
# 4        356          51             36

# %%
df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18979 entries, 0 to 18978
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Balance        18979 non-null  int64
#  1   Power          18979 non-null  int64
#  2   Shot Power     18979 non-null  int64
#  3   Jumping        18979 non-null  int64
#  4   Stamina        18979 non-null  int64
#  5   Strength       18979 non-null  int64
#  6   Long Shots     18979 non-null  int64
#  7   Mentality      18979 non-null  int64
#  8   Aggression     18979 non-null  int64
#  9   Interceptions  18979 non-null  int64
# dtypes: int64(10)
# memory usage: 1.4 MB

# %%
df5.dtypes
# Out:
# Balance          int64
# Power            int64
# Shot Power       int64
# Jumping          int64
# Stamina          int64
# Strength         int64
# Long Shots       int64
# Mentality        int64
# Aggression       int64
# Interceptions    int64
# dtype: object

# %%
df5.describe()
# Out:
#             Balance         Power    Shot Power       Jumping       Stamina  \
# count  18979.000000  18979.000000  18979.000000  18979.000000  18979.000000
# mean      63.925865    296.605195     57.801676     64.577375     62.653986
# std       14.062285     50.732390     13.308747     11.844870     15.804223
# min       12.000000    122.000000     18.000000     15.000000     12.000000
# 25%       56.000000    264.000000     48.000000     58.000000     55.000000
# 50%       66.000000    302.000000     59.000000     65.000000     66.000000
# 75%       74.000000    334.000000     68.000000     73.000000     73.000000
# max       97.000000    444.000000     95.000000     95.000000     97.000000
#
#            Strength    Long Shots     Mentality    Aggression  Interceptions
# count  18979.000000  18979.000000  18979.000000  18979.000000   18979.000000
# mean      64.786922     46.785236    254.199747     55.591285      46.394489
# ...

# %%
df5.duplicated().sum()
# Out:
# 10

# %% [markdown]
# Ouch! we have a total of ten duplicated values in  the dataset lets work on them now

# %%
# remove duplicates based on all columns
df5 = df5.drop_duplicates()

# %% [markdown]
# Let's confirm if the duplicates have been removed successfully

# %%
df5.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Great! the duplicates have been eliminated

# %%
df5.isna().sum()
# Out:
# Balance          0
# Power            0
# Shot Power       0
# Jumping          0
# Stamina          0
# Strength         0
# Long Shots       0
# Mentality        0
# Aggression       0
# Interceptions    0
# dtype: int64

# %% [markdown]
# Great! there are no missing values in the dataset

# %% [markdown]
# # Now lets check on the unique values on the columns and ssee what can be done to them

# %%
df5['Balance'].unique()
# Out:
# array([95, 71, 49, 76, 83, 82, 91, 37, 43, 53, 86, 66, 45, 35, 69, 94, 92,
#        84, 90, 48, 73, 36, 41, 93, 74, 60, 79, 65, 78, 61, 57, 50, 68, 51,
#        54, 77, 81, 39, 75, 58, 87, 85, 63, 38, 88, 67, 72, 62, 80, 44, 46,
#        42, 55, 40, 70, 32, 89, 52, 59, 47, 64, 27, 56, 30, 31, 25, 34, 29,
#        24, 96, 33, 28, 20, 23, 22, 26, 21, 17, 97, 19, 12, 18],
#       dtype=int64)

# %%
df5['Power'].unique()
# Out:
# array([389, 444, 268, 408, 357, 420, 393, 240, 404, 402, 406, 437, 249,
#        284, 400, 403, 358, 381, 382, 273, 424, 264, 316, 361, 355, 328,
#        370, 350, 365, 348, 411, 395, 385, 257, 337, 250, 379, 371, 409,
#        223, 398, 388, 241, 347, 308, 426, 378, 343, 341, 262, 325, 345,
#        359, 399, 421, 396, 315, 253, 368, 336, 340, 366, 387, 369, 375,
#        260, 326, 346, 373, 412, 364, 279, 376, 372, 415, 356, 333, 338,
#        342, 410, 407, 430, 394, 354, 331, 239, 234, 392, 270, 422, 374,
#        360, 391, 300, 335, 242, 327, 215, 397, 321, 390, 339, 383, 265,
#        288, 224, 351, 252, 429, 416, 380, 413, 377, 405, 349, 232, 386,
#        362, 192, 320, 251, 329, 271, 237, 427, 259, 255, 266, 227, 353,
#        258, 243, 263, 291, 302, 306, 332, 363, 256, 247, 301, 287, 322,
#        419, 312, 245, 297, 401, 344, 235, 289, 233, 317, 334, 216, 367,
#        352, 318, 226, 324, 219, 319, 292, 244, 423, 323, 304, 208, 314,
# ...

# %%
df5['Shot Power'].unique()
# Out:
# array([86, 94, 59, 91, 80, 89, 64, 66, 81, 84, 88, 56, 68, 79, 78, 71, 82,
#        70, 55, 76, 61, 83, 51, 52, 90, 87, 62, 72, 77, 74, 50, 57, 58, 85,
#        60, 75, 67, 65, 93, 46, 54, 69, 41, 73, 40, 53, 95, 43, 63, 42, 48,
#        31, 44, 37, 49, 39, 45, 38, 47, 30, 33, 25, 34, 36, 28, 27, 32, 26,
#        35, 23, 22, 29, 20, 24, 21, 18], dtype=int64)

# %%
df5['Jumping'].unique()
# Out:
# array([68, 95, 78, 63, 62, 84, 69, 52, 77, 79, 90, 86, 87, 93, 57, 75, 66,
#        82, 56, 32, 51, 76, 72, 81, 74, 71, 67, 65, 73, 64, 70, 80, 85, 37,
#        89, 60, 49, 50, 83, 58, 53, 59, 88, 38, 92, 34, 61, 46, 43, 36, 91,
#        39, 45, 42, 40, 54, 33, 55, 31, 44, 35, 47, 48, 30, 41, 94, 28, 29,
#        27, 24, 19, 26, 17, 15, 22], dtype=int64)

# %%
df5['Stamina'].unique()
# Out:
# array([72, 84, 41, 89, 81, 76, 85, 32, 86, 35, 75, 88, 90, 38, 43, 78, 79,
#        96, 95, 70, 82, 77, 93, 94, 87, 39, 54, 80, 45, 83, 69, 65, 73, 91,
#        34, 66, 71, 92, 62, 67, 64, 63, 68, 36, 61, 74, 42, 40, 23, 44, 31,
#        57, 20, 37, 29, 30, 56, 60, 52, 48, 58, 25, 51, 26, 27, 59, 28, 53,
#        33, 49, 97, 55, 50, 46, 24, 21, 22, 15, 47, 17, 19, 16, 18, 14, 12],
#       dtype=int64)

# %%
df5['Strength'].unique()
# Out:
# array([69, 78, 74, 50, 86, 75, 76, 92, 70, 91, 80, 85, 65, 72, 67, 60, 84,
#        71, 94, 63, 73, 62, 54, 81, 64, 87, 58, 43, 77, 66, 53, 89, 68, 46,
#        44, 61, 79, 88, 59, 83, 55, 34, 82, 95, 56, 37, 90, 57, 93, 49, 39,
#        51, 52, 40, 48, 41, 47, 35, 42, 33, 45, 32, 38, 30, 31, 36, 29, 27,
#        24, 28, 16, 97, 96, 20, 25, 26, 23], dtype=int64)

# %%
df5['Long Shots'].unique()
# Out:
# array([94, 93, 12, 91, 84, 85, 14, 79, 10, 64, 78, 81, 17, 16, 65, 87, 18,
#        86, 19, 15, 82, 63, 74, 76, 47, 89, 70, 90, 77, 13, 49, 54, 88, 80,
#        53, 58, 51, 73, 66, 75, 83, 30, 46, 35, 71, 61, 72, 69, 43, 48, 62,
#        41, 60, 11, 26, 57, 59, 68, 67,  7, 27, 56, 20, 52, 92, 50, 22, 40,
#        39, 44, 31, 42,  9,  6, 55, 28, 23, 38, 24, 25, 34, 36, 29,  4,  8,
#        45, 33, 37, 21, 32,  5], dtype=int64)

# %%
df5['Mentality'].unique()
# Out:
# array([347, 353, 140, 408, 356, 391, 376, 341, 171, 358, 396, 122, 188,
#        363, 414, 332, 386, 379, 348, 172, 382, 123, 294, 378, 313, 371,
#        331, 412, 345, 377, 161, 306, 387, 339, 135, 360, 138, 369, 359,
#        170, 361, 321, 397, 394, 385, 366, 162, 337, 362, 344, 319, 315,
#        144, 336, 340, 373, 398, 324, 300, 338, 384, 139, 364, 372, 134,
#        354, 342, 308, 322, 383, 263, 149, 304, 367, 357, 390, 291, 279,
#        310, 388, 375, 349, 351, 365, 133, 334, 303, 380, 153, 392, 169,
#        318, 350, 352, 401, 302, 325, 346, 132, 399, 281, 335, 403, 307,
#        368, 141, 126, 328, 245, 131, 320, 127, 421, 400, 137, 374, 305,
#         92, 316, 311, 120, 389, 145, 355, 148, 343, 142, 130, 121, 157,
#        329, 323, 115, 150, 298, 154, 317, 295, 100, 301, 326, 327, 197,
#        273, 287, 370, 290, 103, 393, 312, 297,  89, 271, 299, 124, 333,
#        258, 309, 158, 272, 118, 314, 330, 292, 404, 101, 280, 277, 296,
# ...

# %%
df5['Aggression'].unique()
# Out:
# array([44, 63, 34, 76, 51, 81, 27, 62, 43, 83, 75, 91, 23, 29, 90, 65, 59,
#        89, 48, 38, 25, 87, 54, 60, 73, 74, 69, 85, 70, 86, 32, 40, 31, 77,
#        84, 80, 78, 79, 71, 56, 42, 30, 61, 58, 28, 82, 46, 52, 36, 92, 55,
#        35, 67, 37, 72, 57, 50, 64, 39, 47, 20, 68, 15, 66, 33, 93, 88, 22,
#        24, 45, 17, 18, 26, 21, 11, 41, 53, 19, 12, 49, 94, 16, 95, 13, 14,
#        96, 10,  9], dtype=int64)

# %%
df5['Interceptions'].unique()
# Out:
# array([40, 29, 19, 66, 36, 49, 55, 11, 38, 22, 90, 35, 87, 15, 30, 39, 88,
#        24, 91, 82, 42, 27, 41, 79, 74, 58, 20, 85, 48, 83, 64, 21, 50, 81,
#        78, 28, 86, 26, 34, 52, 37, 80, 25, 56, 23, 47, 45, 77, 84, 44, 53,
#        18, 46, 72, 61, 89, 54, 63, 65, 73, 16, 32, 76, 59, 13, 70, 31, 69,
#        33, 17, 75, 68, 60, 51, 71, 12, 57, 10, 43, 67, 14,  9, 62,  8,  7,
#         6,  4,  5,  3], dtype=int64)

# %% [markdown]
# # Checking for outlers in the various columns in the datset

# %%
# boxplot of Interceptions column

df5.boxplot(column= 'Interceptions')
plt.ylabel("Player's Interceptions")
plt.title("Player's Interceptions Boxplot")
plt.show()

# %% [markdown]
#  interception column has no outliers

# %%
# boxplot of Aggression column

df5.boxplot(column= 'Aggression')
plt.ylabel("Player's Aggression")
plt.title("Player's Aggression Boxplot")
plt.show()

# %% [markdown]
# The aggression column has no outliers

# %%
# boxplot of Interceptions column

df5.boxplot(column= 'Mentality')
plt.ylabel("Player's Mentality")
plt.title("Player's Mentality Boxplot")
plt.show()

# %%
# First quartile\
Q1 = df5['Mentality'].quantile(0.25)

# Second Quartile

Q3 = df5['Mentality'].quantile(0.75)

# interquartile range

IQR = Q3 - Q1

# IQR
IQR
# Out:
# 69.0

# %%
# whisker width

whisker_width = 1.5


# get the outlier records in dataset

Mentality_outliers = df5[(df5['Mentality'] < (Q1 - (whisker_width*IQR))) | (df5['Mentality'] > (Q3 + (whisker_width*IQR)))]


# records with Mentality outliers

Mentality_outliers['Mentality'].to_list()
# Out:
# [408,
#  122,
#  414,
#  123,
#  408,
#  412,
#  401,
#  403,
#  421,
#  401,
#  92,
#  122,
#  120,
#  121,
#  115,
#  403,
#  100,
#  122,
#  103,
#  89,
#  122,
#  124,
#  118,
#  401,
#  121,
#  404,
#  101,
#  109,
#  100,
#  93,
#  122,
#  105,
#  111,
#  119,
#  122,
#  95,
#  99,
#  104,
#  106,
#  109,
#  122,
#  111,
#  103,
#  123,
#  102,
#  113,
#  102,
#  96,
#  121,
#  105,
#  115,
#  124,
#  116,
#  116,
#  112,
#  114,
#  110,
#  114,
#  119,
#  108,
#  117,
#  116,
#  116,
#  115,
#  111,
#  118,
#  84,
#  84,
#  113,
#  97,
#  91,
#  75,
#  112,
#  119,
#  113,
#  110,
#  123,
#  101,
#  118,
#  118,
#  114,
#  122,
#  92,
#  114,
#  114,
#  117,
#  119,
#  104,
#  77,
#  124,
#  122,
#  116,
#  119,
#  82,
#  112,
#  113,
#  96,
#  117,
#  110,
#  117,
#  114,
#  88,
#  123,
#  124,
#  117,
#  90,
#  99,
#  114,
#  111,
#  120,
#  83,
#  116,
#  118,
#  95,
#  112,
#  83,
#  108,
#  102,
#  102,
#  101,
#  112,
#  87,
#  90,
#  89,
#  85,
#  94,
#  96,
#  105,
# ...

# %% [markdown]
# In the mentality column, there are outliers on the values above 400 and the values below 125

# %% [markdown]
# Eliminating the outliers

# %%
# whisker width
whisker_width = 1.5

# get the outlier records FK Accuracyin dataset
Mentality_outliers = df5[(df5['Mentality'] < (Q1 - (whisker_width*IQR))) | (df5['Mentality'] > (Q3 + (whisker_width*IQR)))]

# drop the outliers
df5 = df5.drop(Mentality_outliers.index)

# show the updated boxplot without outliers
df5.boxplot(column='Mentality')
plt.ylabel("Player's Mentality")
plt.title("Player's Mentality Boxplot (without outliers)")
plt.show()

# %% [markdown]
# Great! The outliers have  been successfully eliminated

# %%
# boxplot of Long shots column

df5.boxplot(column= 'Long Shots')
plt.ylabel("Player's Long shots")
plt.title("Player's Long shots Boxplot")
plt.show()

# %% [markdown]
# There are no outliers on the long shots column

# %%
# boxplot of Strength column

df5.boxplot(column= 'Strength')
plt.ylabel("Player's Strength")
plt.title("Player's Strength Boxplot")
plt.show()

# %%
# First quartile\
Q1 = df5['Strength'].quantile(0.25)

# Second Quartile

Q3 = df5['Strength'].quantile(0.75)

# interquartile range

IQR = Q3 - Q1

# IQR
IQR
# Out:
# 16.0

# %%
# whisker width

whisker_width = 1.5


# get the outlier records in dataset

Strength_outliers = df5[(df5['Strength'] < (Q1 - (whisker_width*IQR))) | (df5['Strength'] > (Q3 + (whisker_width*IQR)))]


# records with Strength outliers

Strength_outliers['Strength'].to_list()
# Out:
# [33,
#  32,
#  30,
#  33,
#  30,
#  33,
#  32,
#  33,
#  31,
#  33,
#  31,
#  33,
#  32,
#  29,
#  33,
#  33,
#  30,
#  32,
#  32,
#  32,
#  27,
#  30,
#  31,
#  33,
#  29,
#  30,
#  29,
#  30,
#  33,
#  32,
#  32,
#  31,
#  24,
#  32,
#  30,
#  31,
#  32,
#  27,
#  31,
#  33,
#  31,
#  32,
#  33,
#  30,
#  31,
#  32,
#  32,
#  32,
#  30,
#  32,
#  32,
#  33,
#  31,
#  33,
#  33,
#  28,
#  32,
#  33,
#  30,
#  33,
#  30,
#  32,
#  32,
#  33,
#  33,
#  32,
#  31,
#  31,
#  31,
#  33,
#  31,
#  32,
#  29,
#  31,
#  32,
#  33,
#  32,
#  27,
#  30,
#  32,
#  31,
#  30,
#  28,
#  30,
#  33,
#  31,
#  32,
#  32,
#  29,
#  32,
#  32,
#  31,
#  31,
#  30,
#  30,
#  31,
#  33,
#  33,
#  31,
#  33,
#  33,
#  29,
#  33,
#  30,
#  33,
#  31,
#  33,
#  32,
#  33,
#  30,
#  30,
#  32,
#  25,
#  30,
#  33,
#  33,
#  30,
#  32,
#  30,
#  31,
#  31,
#  32,
#  30,
#  32,
#  32,
#  32,
#  29,
#  33,
#  32,
#  27,
#  33,
#  32,
#  31,
#  33,
#  29,
#  33,
#  31,
#  33,
#  31,
#  33,
#  33,
#  31,
# ...

# %% [markdown]
# On the Strenght column, the outliers are the strenth values below 32

# %% [markdown]
# Eliminating the outliers

# %%
# whisker width
whisker_width = 1.5

# get the outlier records FK Accuracyin dataset
Strength_outliers = df5[(df5['Strength'] < (Q1 - (whisker_width*IQR))) | (df5['Strength'] > (Q3 + (whisker_width*IQR)))]

# drop the outliers
df5 = df5.drop(Strength_outliers.index)

# show the updated boxplot without outliers
df5.boxplot(column='Strength')
plt.ylabel("Player's Strength")
plt.title("Player's Strength Boxplot (without outliers)")
plt.show()

# %% [markdown]
# The outliers eliminated successfully

# %%
# boxplot of Stamina column

df5.boxplot(column= 'Stamina')
plt.ylabel("Player's Stamina")
plt.title("Player's Stamina Boxplot")
plt.show()

# %%
# First quartile\
Q1 = df5['Stamina'].quantile(0.25)

# Second Quartile

Q3 = df5['Stamina'].quantile(0.75)

# interquartile range

IQR = Q3 - Q1

# IQR
IQR
# Out:
# 15.0

# %%
# whisker width

whisker_width = 1.5


# get the outlier records in dataset

Stamina_outliers = df5[(df5['Stamina'] < (Q1 - (whisker_width*IQR))) | (df5['Stamina'] > (Q3 + (whisker_width*IQR)))]


# records with Stamina outliers

Stamina_outliers['Stamina'].to_list()
# Out:
# [32,
#  35,
#  34,
#  35,
#  36,
#  34,
#  34,
#  23,
#  36,
#  34,
#  31,
#  29,
#  34,
#  31,
#  25,
#  32,
#  30,
#  35,
#  35,
#  34,
#  32,
#  35,
#  23,
#  27,
#  32,
#  30,
#  29,
#  32,
#  34,
#  34,
#  32,
#  35,
#  97,
#  32,
#  31,
#  35,
#  35,
#  36,
#  35,
#  31,
#  35,
#  23,
#  29,
#  34,
#  28,
#  24,
#  33,
#  31,
#  29,
#  34,
#  34,
#  34,
#  30,
#  25,
#  27,
#  33,
#  30,
#  36,
#  32,
#  31,
#  32,
#  32,
#  36,
#  34,
#  26,
#  36,
#  28,
#  33,
#  32,
#  31,
#  34,
#  35,
#  32,
#  31,
#  28,
#  36,
#  35,
#  36,
#  34,
#  30,
#  30,
#  34,
#  32,
#  33,
#  36,
#  34,
#  31,
#  34,
#  35,
#  27,
#  30,
#  35,
#  32,
#  36,
#  30,
#  34,
#  28,
#  33,
#  31,
#  31,
#  29,
#  33,
#  25,
#  26,
#  28,
#  20,
#  30,
#  28,
#  30,
#  31,
#  34,
#  28,
#  34,
#  32,
#  30,
#  34,
#  26,
#  30,
#  22,
#  31,
#  31,
#  32,
#  36,
#  31,
#  25,
#  35,
#  27,
#  34,
#  36,
#  34,
#  31,
#  30,
#  25,
#  34,
#  35,
#  32,
#  34,
#  31,
#  32,
#  31,
#  30,
#  30,
# ...

# %% [markdown]
# In the stamina column, the outliers are the stamina values below 28

# %% [markdown]
# Eliminating the outliers

# %%
# whisker width
whisker_width = 1.5

# get the outlier records FK Accuracyin dataset
Stamina_outliers = df5[(df5['Stamina'] < (Q1 - (whisker_width*IQR))) | (df5['Stamina'] > (Q3 + (whisker_width*IQR)))]

# drop the outliers
df5 = df5.drop(Stamina_outliers.index)

# show the updated boxplot without outliers
df5.boxplot(column='Stamina')
plt.ylabel("Player's Stamina")
plt.title("Player's Stamina Boxplot (without outliers)")
plt.show()

# %% [markdown]
# Outliers eliminated successfully

# %%
# boxplot of Jumping column

df5.boxplot(column= 'Jumping')
plt.ylabel("Player's Jumping")
plt.title("Player's Jumping Boxplot")
plt.show()

# %%
# First quartile\
Q1 = df5['Jumping'].quantile(0.25)

# Second Quartile

Q3 = df5['Jumping'].quantile(0.75)

# interquartile range

IQR = Q3 - Q1

# IQR
IQR
# Out:
# 14.0

# %%
# whisker width

whisker_width = 1.5


# get the outlier records in dataset

Jumping_outliers = df5[(df5['Jumping'] < (Q1 - (whisker_width*IQR))) | (df5['Jumping'] > (Q3 + (whisker_width*IQR)))]


# records with Jumping outliers

Jumping_outliers['Jumping'].to_list()
# Out:
# [95,
#  32,
#  37,
#  34,
#  34,
#  32,
#  33,
#  31,
#  33,
#  37,
#  31,
#  35,
#  34,
#  35,
#  31,
#  33,
#  34,
#  35,
#  34,
#  30,
#  36,
#  34,
#  35,
#  37,
#  34,
#  36,
#  37,
#  34,
#  34,
#  33,
#  34,
#  33,
#  34,
#  33,
#  33,
#  32,
#  37,
#  34,
#  33,
#  31,
#  34,
#  33,
#  31,
#  34,
#  34,
#  32,
#  37,
#  37,
#  31,
#  33,
#  32,
#  33,
#  31,
#  34,
#  32,
#  33,
#  32,
#  35,
#  33,
#  32,
#  31,
#  33,
#  34,
#  34,
#  32,
#  33,
#  32,
#  34,
#  33,
#  34,
#  36,
#  35,
#  34,
#  32,
#  34,
#  33,
#  31,
#  32,
#  32,
#  34,
#  37,
#  36,
#  31,
#  33,
#  34,
#  35,
#  34,
#  28,
#  32,
#  31,
#  33,
#  35,
#  35,
#  33,
#  34,
#  29,
#  33,
#  36,
#  33,
#  34,
#  32,
#  32,
#  35,
#  37,
#  37,
#  34,
#  37,
#  32,
#  36,
#  33,
#  35,
#  37,
#  35,
#  34,
#  37,
#  32,
#  33,
#  35,
#  34,
#  33,
#  33,
#  37,
#  34,
#  33,
#  32,
#  31,
#  33,
#  35,
#  31,
#  36,
#  33,
#  32,
#  32,
#  37,
#  34,
#  31,
#  34,
#  35,
#  32,
#  31,
#  36,
#  36,
# ...

# %% [markdown]
# For the jumping column, the outliers lie on the values below 36

# %%
# boxplot of Shot_Power​ column

df5.boxplot(column= 'Shot Power')
plt.ylabel("Player's Shot power")
plt.title("Player's Shot Power Boxplot")
plt.show()

# %% [markdown]
# The Shot power column has no outliers

# %%
# whisker width
whisker_width = 1.5

# get the outlier records FK Accuracyin dataset
Shot_Power_outliers = df5[(df5['Shot Power'] < (Q1 - (whisker_width*IQR))) | (df5['Shot Power'] > (Q3 + (whisker_width*IQR)))]

# drop the outliers
df5 = df5.drop(Shot_Power_outliers.index)

# show the updated boxplot without outliers
df5.boxplot(column='Shot Power')
plt.ylabel("Player's Shot Power")
plt.title("Player's Shot Power​ Shot PowerBoxplot (without outliers)")
plt.show()

# %% [markdown]
# Awesome! Outliers eliminated successfully

# %%
# boxplot of Power column

df5.boxplot(column= 'Power')
plt.ylabel("Player's Power")
plt.title("Player's Power Boxplot")
plt.show()

# %%
# First quartile\
Q1 = df5['Power'].quantile(0.25)

# Second Quartile

Q3 = df5['Power'].quantile(0.75)

# interquartile range

IQR = Q3 - Q1

# IQR
IQR
# Out:
# 55.0

# %%
# whisker width

whisker_width = 1.5


# get the outlier records in dataset

Power_outliers = df5[(df5['Power'] < (Q1 - (whisker_width*IQR))) | (df5['Power'] > (Q3 + (whisker_width*IQR)))]


# records with Power outliers

Power_outliers['Power'].to_list()
# Out:
# [444,
#  437,
#  424,
#  426,
#  430,
#  429,
#  427,
#  424,
#  427,
#  195,
#  196,
#  191,
#  201,
#  202,
#  183,
#  202,
#  194,
#  196,
#  198,
#  200,
#  198]

# %% [markdown]
# On the power column, there are outliers on the Values above 443 and below 159

# %% [markdown]
# Eliminating the outliers

# %%
# whisker width
whisker_width = 1.5

# get the outlier records FK Accuracyin dataset
Power_outliers = df5[(df5['Power'] < (Q1 - (whisker_width*IQR))) | (df5['Power'] > (Q3 + (whisker_width*IQR)))]

# drop the outliers
df5 = df5.drop(Power_outliers.index)

# show the updated boxplot without outliers
df5.boxplot(column='Power')
plt.ylabel("Player's Power")
plt.title("Player's Power​ Shot PowerBoxplot (without outliers)")
plt.show()

# %% [markdown]
# Outliers Elimnated successfully

# %%
# boxplot of Interceptions column

df5.boxplot(column= 'Balance')
plt.ylabel("Player's Balance")
plt.title("Player's Balance Boxplot")
plt.show()

# %%
# First quartile\
Q1 = df5['Balance'].quantile(0.25)

# Second Quartile

Q3 = df5['Balance'].quantile(0.75)

# interquartile range

IQR = Q3 - Q1

# IQR
IQR
# Out:
# 15.0

# %%
# whisker width

whisker_width = 1.5


# get the outlier records in dataset

Balance_outliers = df5[(df5['Balance'] < (Q1 - (whisker_width*IQR))) | (df5['Balance'] > (Q3 + (whisker_width*IQR)))]


# records with Balance​ outliers

Balance_outliers['Balance'].to_list()
# Out:
# [35,
#  35,
#  32,
#  35,
#  37,
#  36,
#  31,
#  37,
#  34,
#  35,
#  31,
#  35,
#  37,
#  32,
#  33,
#  35,
#  34,
#  32,
#  36,
#  32,
#  36,
#  28,
#  32,
#  37,
#  29,
#  30,
#  32,
#  31,
#  36,
#  32,
#  32,
#  36,
#  35,
#  33,
#  32,
#  32,
#  37,
#  34,
#  37,
#  27,
#  35,
#  32,
#  34,
#  30,
#  29,
#  29,
#  35,
#  30,
#  35,
#  35,
#  27,
#  30,
#  33,
#  31,
#  33,
#  28,
#  34,
#  37,
#  31,
#  33,
#  30,
#  29,
#  30,
#  33,
#  34,
#  35,
#  36,
#  34,
#  35,
#  34,
#  35,
#  36,
#  34,
#  36,
#  34,
#  33,
#  34,
#  35,
#  32,
#  34,
#  34,
#  36,
#  34,
#  31,
#  36,
#  30,
#  34,
#  36,
#  36,
#  34,
#  31,
#  33,
#  35,
#  37,
#  34,
#  34,
#  34,
#  31,
#  34,
#  33,
#  36,
#  32,
#  34,
#  35,
#  36,
#  35,
#  32,
#  30,
#  34,
#  37,
#  36,
#  35,
#  35,
#  33,
#  34,
#  27,
#  37,
#  32,
#  33,
#  33,
#  34,
#  33,
#  37,
#  28,
#  32,
#  29,
#  33,
#  30,
#  34,
#  31,
#  33,
#  33,
#  36,
#  33,
#  35,
#  34,
#  36,
#  35,
#  22,
#  34,
#  33,
#  34,
# ...

# %% [markdown]
# On the balance column, the outliers are the values below 29

# %% [markdown]
# Working on the outliers

# %%
# whisker width
whisker_width = 1.5

# get the outlier records FK Accuracyin dataset
Balance_outliers = df5[(df5['Balance'] < (Q1 - (whisker_width*IQR))) | (df5['Balance'] > (Q3 + (whisker_width*IQR)))]

# drop the outliers
df5 = df5.drop(Balance_outliers.index)

# show the updated boxplot without outliers
df5.boxplot(column='Balance')
plt.ylabel("Player's Balance")
plt.title("Player's Balance​ Shot PowerBoxplot (without outliers)")
plt.show()

# %% [markdown]
# Outliers Eliminated succesfully

# %% [markdown]
# Saving the dataset

# %%
# Save the dataset to a CSV file
df5.to_csv('df5_dataset.csv', index=False)

# %% [markdown]
# # Selecting more columns for the df6 dataset

# %%
df.columns
# Out:
# Index(['ID', 'Name', 'LongName', 'photoUrl', 'playerUrl', 'Nationality', 'Age',
#        '↓OVA', 'POT', 'Club', 'Contract', 'Positions', 'Height', 'Weight',
#        'Preferred Foot', 'BOV', 'Best Position', 'Joined', 'Loan Date End',
#        'Value', 'Wage', 'Release Clause', 'Attacking', 'Crossing', 'Finishing',
#        'Heading Accuracy', 'Short Passing', 'Volleys', 'Skill', 'Dribbling',
#        'Curve', 'FK Accuracy', 'Long Passing', 'Ball Control', 'Movement',
#        'Acceleration', 'Sprint Speed', 'Agility', 'Reactions', 'Balance',
#        'Power', 'Shot Power', 'Jumping', 'Stamina', 'Strength', 'Long Shots',
#        'Mentality', 'Aggression', 'Interceptions', 'Positioning', 'Vision',
#        'Penalties', 'Composure', 'Defending', 'Marking', 'Standing Tackle',
#        'Sliding Tackle', 'Goalkeeping', 'GK Diving', 'GK Handling',
#        'GK Kicking', 'GK Positioning', 'GK Reflexes', 'Total Stats',
# ...

# %%
 df6 = df[['Positioning', 'Vision','Penalties', 'Composure', 'Defending', 'Marking', 'Standing Tackle',
       'Sliding Tackle', 'Goalkeeping']]

# %%
df6.head()
# Out:
#    Positioning  Vision  Penalties  Composure  Defending  Marking  \
# 0           93      95         75         96         91       32
# 1           95      82         84         95         84       28
# 2           11      65         11         68         57       27
# 3           88      94         84         91        186       68
# 4           87      90         92         93         94       35
#
#    Standing Tackle  Sliding Tackle  Goalkeeping
# 0               35              24           54
# 1               32              24           58
# 2               12              18          437
# 3               65              53           56
# 4               30              29           59

# %%
df6.describe()
# Out:
#         Positioning        Vision     Penalties    Composure     Defending  \
# count  18979.000000  18979.000000  18979.000000  18979.00000  18979.000000
# mean      50.298962     53.857105     48.057906     58.07366    139.909268
# std       19.428701     13.708574     15.655999     12.07911     61.219472
# min        2.000000      9.000000      6.000000     12.00000     20.000000
# 25%       40.000000     45.000000     39.000000     50.00000     83.000000
# 50%       55.000000     55.000000     49.000000     59.00000    159.000000
# 75%       64.000000     64.000000     60.000000     67.00000    191.000000
# max       95.000000     95.000000     92.000000     96.00000    272.000000
#
#             Marking  Standing Tackle  Sliding Tackle   Goalkeeping
# count  18979.000000     18979.000000    18979.000000  18979.000000
# mean      46.559197        47.705622       45.644449     81.436693
# std       20.139324        21.367690       20.922087     84.665579
# ...

# %%
df6.duplicated().sum()
# Out:
# 11

# %% [markdown]
# There 11 duplicated values let's Eliminste them

# %%
# remove duplicates based on all columns
df6 = df6.drop_duplicates()

# %% [markdown]
# confirming if the duplicates have been eliminated

# %%
df6.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Great! No more duplicates on the dataset

# %%
df6.dtypes
# Out:
# Positioning        int64
# Vision             int64
# Penalties          int64
# Composure          int64
# Defending          int64
# Marking            int64
# Standing Tackle    int64
# Sliding Tackle     int64
# Goalkeeping        int64
# dtype: object

# %%
df6.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18968 entries, 0 to 18978
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Positioning      18968 non-null  int64
#  1   Vision           18968 non-null  int64
#  2   Penalties        18968 non-null  int64
#  3   Composure        18968 non-null  int64
#  4   Defending        18968 non-null  int64
#  5   Marking          18968 non-null  int64
#  6   Standing Tackle  18968 non-null  int64
#  7   Sliding Tackle   18968 non-null  int64
#  8   Goalkeeping      18968 non-null  int64
# dtypes: int64(9)
# memory usage: 1.4 MB

# %%
df6.isna().sum()
# Out:
# Positioning        0
# Vision             0
# Penalties          0
# Composure          0
# Defending          0
# Marking            0
# Standing Tackle    0
# Sliding Tackle     0
# Goalkeeping        0
# dtype: int64

# %% [markdown]
# Graet! There are no missing values

# %% [markdown]
# # Checking if there are any unique values in the datset columns

# %%
df6['Positioning'].unique()
# Out:
# array([93, 95, 11, 88, 87, 94, 91, 13, 47, 92, 72, 12, 90, 73, 80, 85, 20,
#        35, 76, 89, 83, 77, 54, 70, 86, 16, 28, 14, 84, 78, 10, 75, 52, 71,
#        81, 64, 56, 15, 82, 79, 44, 30, 59,  7, 68, 38, 48, 67, 24, 26, 34,
#        69, 74, 32, 66, 62, 65, 51, 18, 31,  9, 25, 49, 55, 63, 27, 61, 17,
#        39, 58, 29, 50, 40, 19,  8, 42, 60, 57, 37, 45, 43, 53,  5,  4, 36,
#         6, 46, 41, 23, 22, 33, 21,  3,  2], dtype=int64)

# %%
df6['Vision'].unique()
# Out:
# array([95, 82, 65, 94, 90, 79, 84, 66, 80, 70, 85, 44, 87, 71, 83, 41, 52,
#        86, 68, 50, 77, 48, 88, 30, 61, 74, 59, 73, 72, 64, 91, 78, 63, 57,
#        89, 62, 56, 69, 42, 67, 27, 76, 81, 55, 75, 60, 49, 45, 58, 22, 53,
#        46, 25, 43, 51, 40, 93, 33, 31, 34, 35, 39, 47, 21, 32, 28, 37, 36,
#        38, 54, 24, 23, 14, 11, 15, 26, 19, 18, 12, 20, 17, 10, 29, 13, 16,
#         9], dtype=int64)

# %%
df6['Penalties'].unique()
# Out:
# array([75, 84, 11, 92, 88, 83, 23, 70, 25, 62, 71, 66, 27, 47, 69, 54, 44,
#        86, 17, 90, 33, 87, 73, 60, 55, 68, 91, 72, 50, 78, 18, 82, 40, 29,
#        45, 43, 64, 24, 59, 46, 56, 81, 67, 49, 61, 74, 58, 63, 79, 38, 80,
#        32, 20, 76, 77, 41, 19, 26, 85, 21, 52, 34, 53, 65, 57, 16, 42, 89,
#        15, 13, 14, 22, 51, 37,  9, 48, 12, 31, 36, 39, 10, 30, 35, 28,  8,
#         7,  6], dtype=int64)

# %%
df6['Composure'].unique()
# Out:
# array([96, 95, 68, 91, 93, 88, 90, 65, 84, 70, 66, 80, 85, 69, 82, 89, 81,
#        87, 83, 86, 67, 92, 94, 57, 78, 79, 75, 45, 61, 76, 58, 62, 77, 74,
#        59, 55, 48, 40, 64, 73, 39, 71, 72, 63, 60, 52, 53, 56, 44, 54, 41,
#        32, 49, 46, 31, 51, 50, 25, 18, 38, 30, 24, 21, 36, 33, 26, 23, 47,
#        22, 28, 34, 35, 37, 43, 27, 12, 42, 17, 29, 13, 19, 14, 16, 20, 15],
#       dtype=int64)

# %%
df6['Defending'].unique()
# Out:
# array([ 91,  84,  57, 186,  94,  96, 122,  50, 100,  48, 272, 259,  54,
#         38,  89, 263,  83, 147, 264, 245, 120,  52, 130, 267, 205, 162,
#        105, 241, 148, 248, 266, 194, 258, 117, 166,  56, 249,  92,  45,
#        214, 140,  99, 150,  59, 251, 262, 243, 195, 160,  40, 114, 236,
#        244, 231,  80, 123, 253, 132, 103, 257, 261,  98,  78, 209, 229,
#        230,  60, 101, 206, 242, 138,  61, 256, 171, 260, 226, 224,  44,
#        131, 113, 240,  77, 232, 225, 109, 228, 247,  93, 121, 238, 111,
#        128, 188, 173, 250, 255,  41, 144, 239, 217, 106, 165, 246, 235,
#        126, 118, 203, 234, 135, 215, 175, 192, 108,  39,  33, 151, 156,
#        174,  47, 216, 237, 102, 227, 161, 233,  67, 213,  75, 212,  36,
#        254, 196,  88,  81, 134,  53, 155, 223,  43, 125,  46,  51, 137,
#         71,  95,  35, 208, 110, 170,  87, 107,  55, 204, 177,  69, 152,
#        163,  37, 181, 252, 159, 133, 124, 207,  82,  97,  65,  42,  79,
# ...

# %%
df6['Marking'].unique()
# Out:
# array([32, 28, 27, 68, 35, 38, 15, 34, 25, 93, 42, 84, 20, 17, 47, 85, 30,
#        89, 82, 29, 56, 91, 72, 59, 79, 49, 83, 86, 50, 60, 94, 41, 57, 78,
#        63, 88, 90,  9, 58, 74, 39, 92, 45, 36, 44, 87, 70, 76, 53, 80, 67,
#        77, 12, 48, 55, 75, 81, 11, 64, 69, 14, 24, 52, 65, 19, 31, 13, 10,
#        66, 71, 54, 46, 22, 40, 18, 51, 37, 43, 61, 26, 73, 21,  7, 33, 62,
#        16, 23,  8,  6,  5,  4,  3], dtype=int64)

# %%
df6['Standing Tackle'].unique()
# Out:
# array([35, 32, 12, 65, 30, 42, 43, 19, 34, 13, 93, 88, 18, 10, 24, 29, 53,
#        90, 84, 48, 15, 36, 89, 27, 73, 54, 41, 83, 59, 67, 87, 64, 14, 55,
#        75, 45, 33, 57, 21, 82, 50, 86, 80, 79, 31, 46, 85, 40, 44, 56, 20,
#        70, 76, 81, 71, 16, 68, 37, 38, 78, 39, 77, 11, 74, 28, 49, 47, 72,
#        61, 51, 22, 17, 52, 63, 23, 60, 25, 26,  9, 62, 58, 66, 69,  7,  8,
#         6,  5], dtype=int64)

# %%
df6['Sliding Tackle'].unique()
# Out:
# array([24, 18, 53, 29, 19, 41, 16, 32, 10, 86, 38, 87, 11, 90, 47, 85, 79,
#        40,  8, 13, 22, 60, 49, 81, 88, 55, 33, 42, 14, 80, 36, 12, 52, 71,
#        46, 83, 65, 84, 34, 82, 77, 78, 74, 20, 43, 35, 69, 70, 30, 68, 45,
#        57, 44, 21, 75, 26, 51, 76, 39, 48, 28, 63, 59, 66, 72, 17, 67, 64,
#        31, 25, 15, 54, 58, 62, 56, 23, 37, 73, 50, 27,  9, 61,  7,  6,  4],
#       dtype=int64)

# %%
df6['Goalkeeping'].unique()
# Out:
# array([ 54,  58, 437,  56,  59,  51,  62, 439,  42,  67, 420, 440,  41,
#         46,  63,  60,  26, 435, 424,  43,  45,  52,  50,  47,  53,  44,
#        418,  15,  48, 416, 153, 413,  65,  64,  20, 423,  49,  55,  66,
#         40,  57, 421,  13,  39,  61, 419,  21, 409,  37, 406, 410,  36,
#        408,  34,  29, 405, 403, 402, 407,  16,  69, 391, 401, 398, 400,
#         22,  68, 396,  38,  78,  73, 399, 390, 393, 395, 397,  80,  70,
#        389, 394, 388,  27,  30,  75,  71, 386,  74, 378, 385, 384, 380,
#        392, 381,  10, 387, 383, 375, 382,  19, 379,  24, 369, 356, 368,
#        373, 370, 372,  72, 374, 376, 364,  25, 367,  17, 377, 371, 365,
#        352, 362, 359, 363, 366,  82,  35, 361, 358,  76, 294,  83, 357,
#        360, 355, 354,  77, 229, 350, 353, 347, 351,  32, 349, 169, 346,
#        348, 343, 345, 339, 342,  33, 341,  28, 119, 337, 338, 340, 344,
#        335,  98, 324, 248, 334, 298, 336, 328, 331, 321, 332,  81,  79,
# ...

# %% [markdown]
# # Checking for the otliers

# %%
# boxplot of Goalkeeong column

df6.boxplot(column= 'Goalkeeping')
plt.ylabel("Player's Goalkeeping")
plt.title("Player's Goalkeeping Boxplot")
plt.show()

# %% [markdown]
# There are sooo many outliers in the goalkeeping column lets identfy and work on them

# %%
# First quartile\
Q1 = df6['Goalkeeping'].quantile(0.25)

# Second Quartile

Q3 = df6['Goalkeeping'].quantile(0.75)

# interquartile range

IQR = Q3 - Q1

# IQR
IQR
# Out:
# 11.0

# %%
# whisker width

whisker_width = 1.5


# get the outlier records in dataset

Goalkeeping_outliers = df6[(df6['Goalkeeping'] < (Q1 - (whisker_width*IQR))) | (df6['Goalkeeping'] > (Q3 + (whisker_width*IQR)))]


# records with Goalkeeping outliers

Goalkeeping_outliers['Goalkeeping'].to_list()
# Out:
# [437,
#  439,
#  439,
#  420,
#  440,
#  26,
#  435,
#  424,
#  418,
#  15,
#  416,
#  153,
#  413,
#  418,
#  20,
#  423,
#  418,
#  418,
#  421,
#  13,
#  419,
#  21,
#  409,
#  406,
#  410,
#  406,
#  410,
#  408,
#  409,
#  29,
#  405,
#  403,
#  402,
#  410,
#  407,
#  16,
#  405,
#  391,
#  401,
#  407,
#  409,
#  398,
#  406,
#  400,
#  401,
#  402,
#  406,
#  400,
#  401,
#  403,
#  22,
#  401,
#  405,
#  396,
#  400,
#  78,
#  400,
#  399,
#  390,
#  393,
#  395,
#  407,
#  397,
#  397,
#  398,
#  395,
#  398,
#  403,
#  80,
#  393,
#  393,
#  78,
#  390,
#  389,
#  395,
#  394,
#  20,
#  397,
#  388,
#  27,
#  30,
#  396,
#  399,
#  21,
#  29,
#  394,
#  397,
#  398,
#  393,
#  26,
#  386,
#  389,
#  386,
#  378,
#  385,
#  390,
#  391,
#  389,
#  384,
#  380,
#  392,
#  21,
#  381,
#  10,
#  387,
#  392,
#  389,
#  390,
#  383,
#  394,
#  375,
#  388,
#  382,
#  382,
#  386,
#  387,
#  391,
#  19,
#  387,
#  21,
#  389,
#  390,
#  387,
#  386,
#  22,
#  385,
#  378,
# ...

# %% [markdown]
# The outliers lie on the values above 75 and the values below 32

# %% [markdown]
# Eliminating outliers

# %%
# whisker width
whisker_width = 1.5

# get the outlier records in dataset
Goalkeeping_outliers = df6[(df6['Goalkeeping'] < (Q1 - (whisker_width*IQR))) | (df6['Goalkeeping'] > (Q3 + (whisker_width*IQR)))]

# drop the outliers
df6 = df6.drop(Goalkeeping_outliers.index)

# show the updated boxplot without outliers
df6.boxplot(column='Goalkeeping')
plt.ylabel("Player's Goalkeeping")
plt.title("Player's Goalkeeping Boxplot (without outliers)")
plt.show()

# %% [markdown]
# The outliers have been eliminated successfully

# %%
# boxplot of Sliding Tackle column

df6.boxplot(column= 'Sliding Tackle')
plt.ylabel("Player's Sliding Tackle")
plt.title("Player's Sliding Tackle Boxplot")
plt.show()

# %% [markdown]
# There are no outliers in the Sliding tackle column

# %%
# boxplot of Standing Tackle column

df6.boxplot(column= 'Standing Tackle')
plt.ylabel("Player's Standing Tackle")
plt.title("Player's Standing Tackle Boxplot")
plt.show()

# %% [markdown]
# There no outliers in the standing Tackle column

# %%
# boxplot of Sliding Tackle column

df6.boxplot(column= 'Marking')
plt.ylabel("Player's Marking")
plt.title("Player's Marking Boxplot")
plt.show()

# %% [markdown]
# There are no outliers on the marking column

# %%
# boxplot of Defending column

df6.boxplot(column= 'Defending')
plt.ylabel("Player's Defending")
plt.title("Player's Defending Boxplot")
plt.show()

# %% [markdown]
# There also no outliers on the Deending column

# %%
# boxplot of Composure column

df6.boxplot(column= 'Composure')
plt.ylabel("Player's Composure")
plt.title("Player's Composure Boxplot")
plt.show()

# %% [markdown]
# There are outliers on the composure column let's deal with them

# %% [markdown]
# Working on the outliers

# %%
# whisker width
whisker_width = 1.5

# get the outlier records in dataset
Composure_outliers = df6[(df6['Composure'] < (Q1 - (whisker_width*IQR))) | (df6['Composure'] > (Q3 + (whisker_width*IQR)))]

# drop the outliers
df6 = df6.drop(Composure_outliers.index)

# show the updated boxplot without outliers
df6.boxplot(column='Composure')
plt.ylabel("Player's Composure")
plt.title("Player's Composure Boxplot (without outliers)")
plt.show()

# %% [markdown]
# Outliers successfully eliminated

# %%
# First quartile\
Q1 = df6['Composure'].quantile(0.25)

# Second Quartile

Q3 = df6['Composure'].quantile(0.75)

# interquartile range

IQR = Q3 - Q1

# IQR
IQR
# Out:
# 14.0

# %%
# whisker width

whisker_width = 1.5


# get the outlier records in dataset

Strength_outliers = df6[(df6['Composure'] < (Q1 - (whisker_width*IQR))) | (df6['Composure'] > (Q3 + (whisker_width*IQR)))]


# records with Composure outliers

Strength_outliers['Composure'].to_list()
# Out:
# []

# %% [markdown]
# On the composure column, the outliers are the values, above  90 and below 25

# %% [markdown]
# Eliminating the outliers

# %%
# whisker width
whisker_width = 1.5

# get the outlier records FK Accuracyin dataset
Composure_outliers = df6[(df6['Composure'] < (Q1 - (whisker_width*IQR))) | (df6['Composure'] > (Q3 + (whisker_width*IQR)))]

# drop the outliers
df6 = df6.drop(Composure_outliers.index)

# show the updated boxplot without outliers
df6.boxplot(column='Composure')
plt.ylabel("Player's Composure")
plt.title("Player's Composure​ Shot PowerBoxplot (without outliers)")
plt.show()

# %% [markdown]
# The outliers reduced successfully

# %%
# boxplot of Penalties column

df6.boxplot(column= 'Penalties')
plt.ylabel("Player's Penalties")
plt.title("Player's Penalties Boxplot")
plt.show()

# %% [markdown]
# There are a few outliers on the penalties column let's see them and work on them

# %%
# First quartile\
Q1 = df6['Penalties'].quantile(0.25)

# Second Quartile

Q3 = df6['Penalties'].quantile(0.75)

# interquartile range

IQR = Q3 - Q1

# IQR
IQR
# Out:
# 19.0

# %%
# whisker width

whisker_width = 1.5


# get the outlier records in dataset

Penalties_outliers = df6[(df6['Penalties'] < (Q1 - (whisker_width*IQR))) | (df6['Penalties'] > (Q3 + (whisker_width*IQR)))]


# records with Penalties outliers

Penalties_outliers['Penalties'].to_list()
# Out:
# [90]

# %% [markdown]
# The outliers are 92, 92, 92, 92, 92, 7, 7, 6, 7, 7, 7

# %% [markdown]
# Eliminatin the  outliers

# %%
# whisker width
whisker_width = 1.5

# get the outlier records FK Accuracyin dataset
Penalties_outliers = df6[(df6['Penalties'] < (Q1 - (whisker_width*IQR))) | (df6['Penalties'] > (Q3 + (whisker_width*IQR)))]

# drop the outliers
df6 = df6.drop(Penalties_outliers.index)

# show the updated boxplot without outliers
df6.boxplot(column='Penalties')
plt.ylabel("Player's Penalties")
plt.title("Player's Penalties​ Shot PowerBoxplot (without outliers)")
plt.show()

# %% [markdown]
# Outliers Eliminated successfully

# %%
# boxplot of Vision column

df6.boxplot(column= 'Vision')
plt.ylabel("Player's Vision")
plt.title("Player's Vision Boxplot")
plt.show()

# %%
# First quartile\
Q1 = df6['Vision'].quantile(0.25)

# Second Quartile

Q3 = df6['Vision'].quantile(0.75)

# interquartile range

IQR = Q3 - Q1

# IQR
IQR
# Out:
# 16.0

# %%
# whisker width

whisker_width = 1.5


# get the outlier records in dataset

Vision_outliers = df6[(df6['Vision'] < (Q1 - (whisker_width*IQR))) | (df6['Vision'] > (Q3 + (whisker_width*IQR)))]


# records with Vision outliers

Vision_outliers['Vision'].to_list()
# Out:
# [22,
#  22,
#  17,
#  20,
#  18,
#  13,
#  19,
#  20,
#  19,
#  22,
#  19,
#  21,
#  21,
#  17,
#  20,
#  21,
#  22,
#  21,
#  20,
#  22,
#  22,
#  22,
#  22,
#  22,
#  22,
#  19,
#  16,
#  20,
#  22,
#  22,
#  15,
#  17,
#  20,
#  21,
#  20,
#  22,
#  19,
#  19]

# %% [markdown]
# The outliers are on the values above 92 and below 17

# %% [markdown]
# Eliminating the outliers

# %%
# whisker width
whisker_width = 1.5

# get the outlier records FK Accuracyin dataset
Vision_outliers = df6[(df6['Vision'] < (Q1 - (whisker_width*IQR))) | (df6['Vision'] > (Q3 + (whisker_width*IQR)))]

# drop the outliers
df6 = df6.drop(Vision_outliers.index)

# show the updated boxplot without outliers
df6.boxplot(column='Vision')
plt.ylabel("Player's Vision")
plt.title("Player's Vision​ Shot PowerBoxplot (without outliers)")
plt.show()

# %% [markdown]
# Successfully eliminated

# %%
# boxplot of Positioning column

df6.boxplot(column= 'Positioning')
plt.ylabel("Player's Positioning")
plt.title("Player's positioning Boxplot")
plt.show()

# %% [markdown]
# The column has some few outliers

# %%
# First quartile\
Q1 = df6['Positioning'].quantile(0.25)

# Second Quartile

Q3 = df6['Positioning'].quantile(0.75)

# interquartile range

IQR = Q3 - Q1

# IQR
IQR
# Out:
# 17.0

# %%
# whisker width

whisker_width = 1.5


# get the outlier records in dataset

Positioning_outliers = df6[(df6['Positioning'] < (Q1 - (whisker_width*IQR))) | (df6['Positioning'] > (Q3 + (whisker_width*IQR)))]


# records with Positioning outliers

Positioning_outliers['Positioning'].to_list()
# Out:
# [16,
#  21,
#  20,
#  21,
#  12,
#  21,
#  20,
#  21,
#  20,
#  18,
#  13,
#  20,
#  20,
#  20,
#  16,
#  21,
#  13,
#  19,
#  18,
#  20,
#  21,
#  21,
#  21,
#  20,
#  20,
#  18,
#  21,
#  21,
#  20,
#  21,
#  21,
#  21,
#  20,
#  20,
#  12,
#  20,
#  21,
#  21,
#  21,
#  13,
#  21,
#  18,
#  21,
#  21,
#  20,
#  21,
#  21,
#  21,
#  15,
#  17,
#  21,
#  20,
#  18,
#  12,
#  13,
#  19,
#  20,
#  20,
#  20,
#  21,
#  21,
#  21,
#  19,
#  21,
#  21,
#  21,
#  21,
#  21,
#  21,
#  21,
#  21,
#  21,
#  21,
#  18,
#  21,
#  18,
#  17,
#  19,
#  21,
#  21,
#  15,
#  20,
#  19,
#  21,
#  20,
#  21,
#  21,
#  21,
#  19,
#  21,
#  16,
#  20,
#  20,
#  21,
#  21,
#  21,
#  17,
#  21,
#  21,
#  21,
#  21,
#  21,
#  21,
#  21,
#  13,
#  19,
#  21,
#  21,
#  21,
#  21,
#  18,
#  21,
#  20,
#  21,
#  21,
#  19,
#  21,
#  20,
#  19,
#  20,
#  20,
#  20,
#  18,
#  21,
#  20,
#  21,
#  21,
#  21,
#  20,
#  21,
#  21,
#  21,
#  21,
#  21,
#  21,
#  20,
#  20,
#  21,
#  21,
#  21,
#  21,
#  20,
# ...

# %% [markdown]
# The following are the outliers in the column positioning. 3, 3, 2, 2, 3, 3, 3, 2, 3, 2, 3

# %% [markdown]
# Working on the outliers

# %%
# whisker width
whisker_width = 1.5

# get the outlier records FK Accuracyin dataset
Positioning_outliers = df6[(df6['Positioning'] < (Q1 - (whisker_width*IQR))) | (df6['Positioning'] > (Q3 + (whisker_width*IQR)))]

# drop the outliers
df6 = df6.drop(Positioning_outliers.index)

# show the updated boxplot without outliers
df6.boxplot(column='Positioning')
plt.ylabel("Player's Positioning")
plt.title("Player's Positioning​ Shot PowerBoxplot (without outliers)")
plt.show()

# %% [markdown]
# Saving the dataset to a csv file

# %%
# Save the dataset to a CSV file
df6.to_csv('df6_dataset.csv', index=False)

# %% [markdown]
# # Selecting the columns for the df7 dataset

# %%
df.columns
# Out:
# Index(['ID', 'Name', 'LongName', 'photoUrl', 'playerUrl', 'Nationality', 'Age',
#        '↓OVA', 'POT', 'Club', 'Contract', 'Positions', 'Height', 'Weight',
#        'Preferred Foot', 'BOV', 'Best Position', 'Joined', 'Loan Date End',
#        'Value', 'Wage', 'Release Clause', 'Attacking', 'Crossing', 'Finishing',
#        'Heading Accuracy', 'Short Passing', 'Volleys', 'Skill', 'Dribbling',
#        'Curve', 'FK Accuracy', 'Long Passing', 'Ball Control', 'Movement',
#        'Acceleration', 'Sprint Speed', 'Agility', 'Reactions', 'Balance',
#        'Power', 'Shot Power', 'Jumping', 'Stamina', 'Strength', 'Long Shots',
#        'Mentality', 'Aggression', 'Interceptions', 'Positioning', 'Vision',
#        'Penalties', 'Composure', 'Defending', 'Marking', 'Standing Tackle',
#        'Sliding Tackle', 'Goalkeeping', 'GK Diving', 'GK Handling',
#        'GK Kicking', 'GK Positioning', 'GK Reflexes', 'Total Stats',
# ...

# %%
df7= df[['GK Diving', 'GK Handling','GK Kicking', 'GK Positioning', 'GK Reflexes', 'Total Stats',
       'Base Stats', 'W/F', 'SM', 'A/W']]

# %%
df7.head()
# Out:
#    GK Diving  GK Handling  GK Kicking  GK Positioning  GK Reflexes  \
# 0          6           11          15              14            8
# 1          7           11          15              14           11
# 2         87           92          78              90           90
# 3         15           13           5              10           13
# 4          9            9          15              15           11
#
#    Total Stats  Base Stats  W/F  SM     A/W
# 0         2231         466  4 ★  4★  Medium
# 1         2221         464  4 ★  5★    High
# 2         1413         489  3 ★  1★  Medium
# 3         2304         485  5 ★  4★    High
# 4         2175         451  5 ★  5★    High

# %%
df7.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18979 entries, 0 to 18978
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   GK Diving       18979 non-null  int64
#  1   GK Handling     18979 non-null  int64
#  2   GK Kicking      18979 non-null  int64
#  3   GK Positioning  18979 non-null  int64
#  4   GK Reflexes     18979 non-null  int64
#  5   Total Stats     18979 non-null  int64
#  6   Base Stats      18979 non-null  int64
#  7   W/F             18979 non-null  object
#  8   SM              18979 non-null  object
#  9   A/W             18979 non-null  object
# dtypes: int64(7), object(3)
# memory usage: 1.4+ MB

# %%
df7.dtypes
# Out:
# GK Diving          int64
# GK Handling        int64
# GK Kicking         int64
# GK Positioning     int64
# GK Reflexes        int64
# Total Stats        int64
# Base Stats         int64
# W/F               object
# SM                object
# A/W               object
# dtype: object

# %%
df7.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Great! There are no duplicates in the dataset

# %%
df7.isna().sum()
# Out:
# GK Diving         0
# GK Handling       0
# GK Kicking        0
# GK Positioning    0
# GK Reflexes       0
# Total Stats       0
# Base Stats        0
# W/F               0
# SM                0
# A/W               0
# dtype: int64

# %% [markdown]
# Nice! There are no missing values in the dataset

# %%
df7.describe()
# Out:
#           GK Diving   GK Handling    GK Kicking  GK Positioning   GK Reflexes  \
# count  18979.000000  18979.000000  18979.000000    18979.000000  18979.000000
# mean      16.416302     16.207124     16.076453       16.217187     16.519627
# std       17.554194     16.816305     16.491103       17.002239     17.854079
# min        2.000000      2.000000      2.000000        2.000000      2.000000
# 25%        8.000000      8.000000      8.000000        8.000000      8.000000
# 50%       11.000000     11.000000     11.000000       11.000000     11.000000
# 75%       14.000000     14.000000     14.000000       14.000000     14.000000
# max       90.000000     92.000000     93.000000       91.000000     90.000000
#
#         Total Stats    Base Stats
# count  18979.000000  18979.000000
# mean    1595.286949    355.702197
# std      269.874789     40.761117
# min      747.000000    232.000000
# 25%     1452.000000    327.000000
# 50%     1627.000000    356.000000
# ...

# %%
df7.hist(figsize=(10,8))
# Out:
# array([[<AxesSubplot:title={'center':'GK Diving'}>,
#         <AxesSubplot:title={'center':'GK Handling'}>,
#         <AxesSubplot:title={'center':'GK Kicking'}>],
#        [<AxesSubplot:title={'center':'GK Positioning'}>,
#         <AxesSubplot:title={'center':'GK Reflexes'}>,
#         <AxesSubplot:title={'center':'Total Stats'}>],
#        [<AxesSubplot:title={'center':'Base Stats'}>, <AxesSubplot:>,
#         <AxesSubplot:>]], dtype=object)

# %%
sns.pairplot(df7)

# %% [markdown]
# # Checking for unique values in the columns of the dataset

# %%
df7['GK Diving'].unique()
# Out:
# array([ 6,  7, 87, 15,  9, 14, 86, 13, 88, 10, 84, 11,  8,  5, 12, 90,  3,
#        27, 89, 80, 16, 85,  2, 82, 79, 83,  4, 81, 77, 18, 78, 17, 75, 74,
#        76, 73, 71, 72, 52, 68, 70, 54, 69, 32, 66, 65, 67, 61, 22, 64, 23,
#        40, 63, 55, 19, 50, 62, 58, 60, 59, 56, 57, 53, 51, 49, 46, 48, 47,
#        45], dtype=int64)

# %%
df7['GK Handling'].unique()
# Out:
# array([11, 92, 13,  9,  6, 14, 88,  5, 85, 10, 89, 87,  8, 15, 12,  4, 82,
#        81,  3,  7, 25, 86, 83,  2, 80, 16, 77, 79, 78, 76, 84, 75, 72, 74,
#        71, 69, 73, 70, 67, 68, 65, 61, 62, 64, 41, 63, 66, 33, 22, 17, 57,
#        18, 54, 55, 59, 49, 19, 40, 60, 58, 43, 45, 53, 47, 56, 51, 52, 50,
#        48, 46], dtype=int64)

# %%
df7['GK Kicking'].unique()
# Out:
# array([15, 78,  5, 12,  9, 85,  7, 88, 13, 16, 74, 91,  6, 10,  4, 93, 11,
#        73, 14, 75,  2, 31, 68, 76,  8, 80, 82,  3, 87, 72, 83, 77, 79, 81,
#        69, 71, 20, 67, 70, 64, 65, 63, 44, 60, 84, 54, 48, 61, 18, 66, 17,
#        59, 62, 90, 43, 38, 58, 57, 28, 40, 53, 23, 47, 46, 19, 51, 55, 52,
#        56, 22, 30, 25, 42, 35, 21, 49, 50, 36, 45], dtype=int64)

# %%
df7['GK Positioning'].unique()
# Out:
# array([14, 90, 10, 15,  8, 11, 91, 88,  7, 12, 85, 86,  5, 89, 13,  6, 82,
#         4,  9, 87, 33, 84, 16, 83,  2,  3, 79, 81, 80, 76, 78, 19, 77, 17,
#        75, 74, 73, 71, 18, 72, 70, 69, 66, 68, 40, 64, 20, 32, 67, 62, 65,
#        63, 24, 23, 50, 55, 58, 51, 59, 56, 61, 57, 60, 46, 54, 53, 52, 47,
#        49, 48, 43, 45, 42, 38, 44, 41], dtype=int64)

# %%
df7['GK Reflexes'].unique()
# Out:
# array([ 8, 11, 90, 13, 10, 14, 89,  6, 12, 88,  7,  9, 15,  5,  3, 37, 85,
#        86,  4, 16, 82, 83, 84, 87, 78, 80, 20, 18, 79, 81, 19, 77, 17,  2,
#        74, 71, 76, 73, 75, 72, 69, 46, 66, 51, 70, 34, 67, 23, 68, 45, 65,
#        21, 59, 54, 47, 61, 64, 63, 62, 60, 58, 56, 57, 55, 53, 50, 52, 49,
#        48, 44], dtype=int64)

# %%
df7['Total Stats'].unique()
# Out:
# array([2231, 2221, 1413, ...,  757,  747,  956], dtype=int64)

# %%
df7['Base Stats'].unique()
# Out:
# array([466, 464, 489, 485, 451, 457, 470, 490, 484, 455, 469, 463, 468,
#        497, 442, 439, 473, 452, 498, 449, 477, 401, 446, 447, 465, 430,
#        461, 422, 476, 460, 453, 467, 471, 399, 424, 441, 459, 438, 437,
#        454, 428, 445, 431, 474, 421, 435, 448, 475, 403, 444, 443, 419,
#        405, 420, 423, 396, 388, 482, 478, 385, 394, 480, 433, 450, 462,
#        456, 436, 434, 429, 400, 440, 425, 410, 458, 398, 413, 373, 406,
#        408, 472, 426, 407, 432, 427, 415, 481, 417, 372, 380, 418, 383,
#        414, 409, 412, 411, 386, 362, 402, 390, 404, 391, 416, 375, 389,
#        361, 397, 366, 392, 393, 382, 368, 387, 352, 376, 384, 378, 379,
#        341, 354, 369, 395, 357, 381, 377, 344, 360, 370, 338, 333, 367,
#        363, 349, 355, 345, 358, 348, 374, 351, 343, 342, 353, 321, 350,
#        365, 364, 371, 327, 331, 359, 347, 356, 339, 319, 317, 335, 346,
#        329, 315, 324, 322, 325, 332, 336, 337, 330, 316, 313, 306, 307,
# ...

# %%
df7['W/F'].unique()
# Out:
# array(['4 ★', '3 ★', '5 ★', '2 ★', '1 ★'], dtype=object)

# %%
df7['SM'].unique()
# Out:
# array(['4★', '5★', '1★', '2★', '3★'], dtype=object)

# %%
df7['A/W'].unique()
# Out:
# array(['Medium', 'High', 'Low'], dtype=object)

# %% [markdown]
# # Checking for possible outliers

# %%
# boxplot of Bse stats column

df7.boxplot(column= 'Base Stats')
plt.ylabel("Player's Base Stats")
plt.title("Player's Base Stats Boxplot")
plt.show()

# %%
# First quartile\
Q1 = df7['Base Stats'].quantile(0.25)

# Second Quartile

Q3 = df7['Base Stats'].quantile(0.75)

# interquartile range

IQR = Q3 - Q1

# IQR
IQR
# Out:
# 57.0

# %%
# whisker width

whisker_width = 1.5


# get the outlier records in dataset

Base_Stats_outliers = df7[(df7['Base Stats'] < (Q1 - (whisker_width*IQR))) | (df7['Base Stats'] > (Q3 + (whisker_width*IQR)))]


# records with Base_Stats outliers

Base_Stats_outliers['Base Stats'].to_list()
# Out:
# [489,
#  485,
#  470,
#  490,
#  484,
#  497,
#  473,
#  498,
#  477,
#  476,
#  471,
#  476,
#  476,
#  476,
#  474,
#  471,
#  475,
#  474,
#  470,
#  475,
#  482,
#  478,
#  480,
#  476,
#  470,
#  471,
#  478,
#  474,
#  474,
#  470,
#  478,
#  471,
#  470,
#  478,
#  472,
#  478,
#  473,
#  481,
#  233,
#  239,
#  240,
#  238,
#  239,
#  241,
#  240,
#  241,
#  238,
#  232]

# %% [markdown]
# The outliers lies on the values above 469 and the values below 242

# %% [markdown]
# Working on the outliers

# %%
# whisker width
whisker_width = 1.5

# get the outlier records FK Accuracyin dataset
Base_Stats_outliers = df7[(df7['Base Stats'] < (Q1 - (whisker_width*IQR))) | (df7['Base Stats'] > (Q3 + (whisker_width*IQR)))]

# drop the outliers
df7 = df7.drop(Base_Stats_outliers.index)

# show the updated boxplot without outliers
df7.boxplot(column='Base Stats')
plt.ylabel("Player's Base Stats")
plt.title("Player's Base Stats​  Boxplot (without outliers)")
plt.show()

# %%
# boxplot of Total stats column

df7.boxplot(column= 'Total Stats')
plt.ylabel("Player's Total Stats")
plt.title("Player's Total Stats Boxplot")
plt.show()

# %%
# First quartile\
Q1 = df7['Total Stats'].quantile(0.25)

# Second Quartile

Q3 = df7['Total Stats'].quantile(0.75)

# interquartile range

IQR = Q3 - Q1

# IQR
IQR
# Out:
# 328.0

# %%
# whisker width

whisker_width = 1.5


# get the outlier records in dataset

Total_Stats_outliers = df7[(df7['Total Stats'] < (Q1 - (whisker_width*IQR))) | (df7['Total Stats'] > (Q3 + (whisker_width*IQR)))]


# records with Total_Stats outliers

Total_Stats_outliers['Total Stats'].to_list()
# Out:
# [2288,
#  2316,
#  951,
#  915,
#  930,
#  920,
#  914,
#  911,
#  944,
#  957,
#  903,
#  949,
#  911,
#  919,
#  918,
#  935,
#  942,
#  926,
#  931,
#  882,
#  955,
#  927,
#  906,
#  958,
#  890,
#  915,
#  952,
#  942,
#  906,
#  892,
#  954,
#  923,
#  903,
#  951,
#  904,
#  935,
#  948,
#  945,
#  936,
#  951,
#  918,
#  921,
#  943,
#  918,
#  924,
#  920,
#  947,
#  943,
#  940,
#  936,
#  904,
#  958,
#  911,
#  919,
#  920,
#  933,
#  936,
#  935,
#  913,
#  874,
#  951,
#  957,
#  902,
#  923,
#  921,
#  913,
#  917,
#  925,
#  881,
#  877,
#  912,
#  897,
#  940,
#  950,
#  873,
#  907,
#  902,
#  913,
#  941,
#  859,
#  935,
#  887,
#  926,
#  851,
#  907,
#  949,
#  959,
#  955,
#  906,
#  933,
#  936,
#  957,
#  926,
#  913,
#  895,
#  933,
#  890,
#  916,
#  885,
#  940,
#  935,
#  946,
#  916,
#  935,
#  928,
#  957,
#  928,
#  884,
#  905,
#  862,
#  940,
#  904,
#  882,
#  895,
#  946,
#  929,
#  949,
#  923,
#  924,
#  913,
#  926,
#  881,
#  948,
#  894,
# ...

# %% [markdown]
# The outliers lie on the values above 2278 and below 960

# %% [markdown]
# working on the outliers

# %%
# whisker width
whisker_width = 1.5

# get the outlier records FK Accuracyin dataset
Total_Stats_outliers = df7[(df7['Total Stats'] < (Q1 - (whisker_width*IQR))) | (df7['Total Stats'] > (Q3 + (whisker_width*IQR)))]

# drop the outliers
df7 = df7.drop(Total_Stats_outliers.index)

# show the updated boxplot without outliers
df7.boxplot(column='Total Stats')
plt.ylabel("Player's Total Stats")
plt.title("Player's Total Stats​  Boxplot (without outliers)")
plt.show()

# %%
# boxplot of GK Reflexes column

df7.boxplot(column= 'GK Reflexes')
plt.ylabel("Player's GK reflexes")
plt.title("Player's GK Reflexes Boxplot")
plt.show()

# %%
# First quartile\
Q1 = df7['GK Reflexes'].quantile(0.25)

# Second Quartile

Q3 = df7['GK Reflexes'].quantile(0.75)

# interquartile range

IQR = Q3 - Q1

# IQR
IQR
# Out:
# 6.0

# %%
# whisker width

whisker_width = 1.5


# get the outlier records in dataset

GK_Reflexes_outliers = df7[(df7['GK Reflexes'] < (Q1 - (whisker_width*IQR))) | (df7['GK Reflexes'] > (Q3 + (whisker_width*IQR)))]


# records with GK_Reflexes outliers

GK_Reflexes_outliers['GK Reflexes'].to_list()
# Out:
# [88,
#  88,
#  89,
#  86,
#  88,
#  82,
#  89,
#  83,
#  84,
#  86,
#  88,
#  86,
#  86,
#  87,
#  84,
#  85,
#  84,
#  87,
#  84,
#  83,
#  82,
#  84,
#  88,
#  85,
#  78,
#  84,
#  84,
#  80,
#  87,
#  86,
#  82,
#  82,
#  78,
#  83,
#  82,
#  83,
#  86,
#  82,
#  88,
#  85,
#  79,
#  82,
#  81,
#  82,
#  83,
#  83,
#  82,
#  77,
#  83,
#  80,
#  81,
#  79,
#  84,
#  86,
#  81,
#  82,
#  80,
#  83,
#  82,
#  84,
#  82,
#  81,
#  82,
#  81,
#  81,
#  79,
#  84,
#  83,
#  82,
#  79,
#  80,
#  84,
#  79,
#  84,
#  80,
#  80,
#  83,
#  78,
#  79,
#  80,
#  82,
#  82,
#  84,
#  79,
#  78,
#  78,
#  81,
#  77,
#  80,
#  79,
#  80,
#  80,
#  74,
#  77,
#  79,
#  71,
#  80,
#  79,
#  80,
#  79,
#  78,
#  78,
#  79,
#  80,
#  81,
#  79,
#  79,
#  78,
#  79,
#  78,
#  80,
#  81,
#  80,
#  78,
#  82,
#  77,
#  76,
#  80,
#  77,
#  76,
#  78,
#  83,
#  76,
#  76,
#  77,
#  78,
#  73,
#  78,
#  80,
#  78,
#  78,
#  80,
#  81,
#  74,
#  76,
#  77,
#  80,
#  77,
#  79,
#  77,
#  79,
#  74,
# ...

# %% [markdown]
# ❤💋The outliers lie on the values above 33

# %% [markdown]
# Working on the outliers

# %%
# whisker width
whisker_width = 1.5

# get the outlier records FK Accuracyin dataset
GK_Reflexes_outliers = df7[(df7['GK Reflexes'] < (Q1 - (whisker_width*IQR))) | (df7['GK Reflexes'] > (Q3 + (whisker_width*IQR)))]

# drop the outliers
df7 = df7.drop(GK_Reflexes_outliers.index)

# show the updated boxplot without outliers
df7.boxplot(column='GK Reflexes')
plt.ylabel("Player's GK Reflexes")
plt.title("Player's GK Reflexes​  Boxplot (without outliers)")
plt.show()

# %% [markdown]
# Outliers eliminated successfully

# %%
# boxplot of GK Positioning column

df7.boxplot(column= 'GK Positioning')
plt.ylabel("Player's GK Positioning")
plt.title("Player's GK Positioning Boxplot")
plt.show()

# %%
# First quartile\
Q1 = df7['GK Positioning'].quantile(0.25)

# Second Quartile

Q3 = df7['GK Positioning'].quantile(0.75)

# interquartile range

IQR = Q3 - Q1

# IQR
IQR
# Out:
# 5.0

# %%
# whisker width

whisker_width = 1.5


# get the outlier records in dataset

GK_Positioning_outliers = df7[(df7['GK Positioning'] < (Q1 - (whisker_width*IQR))) | (df7['GK Positioning'] > (Q3 + (whisker_width*IQR)))]


# records with GK_Positioning outliers

GK_Positioning_outliers['GK Positioning'].to_list()
# Out:
# [24, 23]

# %% [markdown]
# The outliers lie on the values above 31

# %% [markdown]
# Eliminating the outliers

# %%
# whisker width
whisker_width = 1.5

# get the outlier records FK Accuracyin dataset
GK_Positioning_outliers = df7[(df7['GK Positioning'] < (Q1 - (whisker_width*IQR))) | (df7['GK Positioning'] > (Q3 + (whisker_width*IQR)))]

# drop the outliers
df7 = df7.drop(GK_Positioning_outliers.index)

# show the updated boxplot without outliers
df7.boxplot(column='GK Positioning')
plt.ylabel("Player's GK Positioning")
plt.title("Player's GK Positioning​  Boxplot (without outliers)")
plt.show()

# %% [markdown]
# The outliers have been eliminated successfully

# %%
# boxplot of GK Kicking column

df7.boxplot(column= 'GK Kicking')
plt.ylabel("Player's GK Kicking")
plt.title("Player's GK Kicking Boxplot")
plt.show()

# %%
# First quartile\
Q1 = df7['GK Kicking'].quantile(0.25)

# Second Quartile

Q3 = df7['GK Kicking'].quantile(0.75)

# interquartile range

IQR = Q3 - Q1

# IQR
IQR
# Out:
# 5.0

# %%
# whisker width

whisker_width = 1.5


# get the outlier records in dataset

GK_Kicking_outliers = df7[(df7['GK Kicking'] < (Q1 - (whisker_width*IQR))) | (df7['GK Kicking'] > (Q3 + (whisker_width*IQR)))]


# records with GK_Kicking outliers

GK_Kicking_outliers['GK Kicking'].to_list()
# Out:
# [23, 22, 30, 25, 23, 21, 36]

# %% [markdown]
# The outliers are on all the values above 30

# %% [markdown]
# Eliminating the outliers

# %%
# whisker width
whisker_width = 1.5

# get the outlier records FK Accuracyin dataset
GK_Kicking_outliers = df7[(df7['GK Kicking'] < (Q1 - (whisker_width*IQR))) | (df7['GK Kicking'] > (Q3 + (whisker_width*IQR)))]

# drop the outliers
df7 = df7.drop(GK_Kicking_outliers.index)

# show the updated boxplot without outliers
df7.boxplot(column='GK Kicking')
plt.ylabel("Player's GK Kicking")
plt.title("Player's GK Kicking​  Boxplot (without outliers)")
plt.show()

# %% [markdown]
# The outliers have successfully been eliminated

# %%
# boxplot of GK Handling column

df7.boxplot(column= 'GK Handling')
plt.ylabel("Player's GK Handling")
plt.title("Player's GK Handling Boxplot")
plt.show()

# %%
# First quartile\
Q1 = df7['GK Handling'].quantile(0.25)

# Second Quartile

Q3 = df7['GK Handling'].quantile(0.75)

# interquartile range

IQR = Q3 - Q1

# IQR
IQR
# Out:
# 5.0

# %%
# whisker width

whisker_width = 1.5


# get the outlier records in dataset

GK_Handling_outliers = df7[(df7['GK Handling'] < (Q1 - (whisker_width*IQR))) | (df7['GK Handling'] > (Q3 + (whisker_width*IQR)))]


# records with GK_Handling outliers

GK_Handling_outliers['GK Handling'].to_list()
# Out:
# []

# %% [markdown]
# The outliers lie on the values above32

# %% [markdown]
# let's eliminate the outliers

# %%
# whisker width
whisker_width = 1.5

# get the outlier records GK Handling in dataset
GK_Handling_outliers = df7[(df7['GK Handling'] < (Q1 - (whisker_width*IQR))) | (df7['GK Kicking'] > (Q3 + (whisker_width*IQR)))]

# drop the outliers
df7 = df7.drop(GK_Handling_outliers.index)

# show the updated boxplot without outliers
df7.boxplot(column='GK Handling')
plt.ylabel("Player's GK Handling")
plt.title("Player's GGK Handling​  Boxplot (without outliers)")
plt.show()

# %% [markdown]
# succesfully eliminated

# %%
# boxplot of GK Diving column

df7.boxplot(column= 'GK Diving')
plt.ylabel("Player's GK Diving")
plt.title("Player's GK Diving Boxplot")
plt.show()

# %%
# First quartile\
Q1 = df7['GK Diving'].quantile(0.25)

# Second Quartile

Q3 = df7['GK Diving'].quantile(0.75)

# interquartile range

IQR = Q3 - Q1

# IQR
IQR
# Out:
# 5.0

# %%
# whisker width

whisker_width = 1.5


# get the outlier records in dataset

GK_Diving_outliers = df7[(df7['GK Diving'] < (Q1 - (whisker_width*IQR))) | (df7['GK Diving'] > (Q3 + (whisker_width*IQR)))]


# records with GK_Diving outliers

GK_Diving_outliers['GK Diving'].to_list()
# Out:
# []

# %% [markdown]
# The outliers are on the values above 26

# %% [markdown]
# Eliminating the outliers

# %%
# whisker width
whisker_width = 1.5

# get the outlier records GK Handling in dataset
GK_Diving_outliers = df7[(df7['GK Diving'] < (Q1 - (whisker_width*IQR))) | (df7['GK Diving'] > (Q3 + (whisker_width*IQR)))]

# drop the outliers
df7 = df7.drop(GK_Diving_outliers.index)

# show the updated boxplot without outliers
df7.boxplot(column='GK Diving')
plt.ylabel("Player's GK Diving")
plt.title("Player's GK Diving​  Boxplot (without outliers)")
plt.show()

# %% [markdown]
# outliers successfully eliminated

# %% [markdown]
# Saving the csv file

# %%
# Save the dataset to a CSV file
df7.to_csv('df7_dataset.csv', index=False)

# %% [markdown]
# # Selecting the columns for the last dataset df8

# %%
df.columns
# Out:
# Index(['ID', 'Name', 'LongName', 'photoUrl', 'playerUrl', 'Nationality', 'Age',
#        '↓OVA', 'POT', 'Club', 'Contract', 'Positions', 'Height', 'Weight',
#        'Preferred Foot', 'BOV', 'Best Position', 'Joined', 'Loan Date End',
#        'Value', 'Wage', 'Release Clause', 'Attacking', 'Crossing', 'Finishing',
#        'Heading Accuracy', 'Short Passing', 'Volleys', 'Skill', 'Dribbling',
#        'Curve', 'FK Accuracy', 'Long Passing', 'Ball Control', 'Movement',
#        'Acceleration', 'Sprint Speed', 'Agility', 'Reactions', 'Balance',
#        'Power', 'Shot Power', 'Jumping', 'Stamina', 'Strength', 'Long Shots',
#        'Mentality', 'Aggression', 'Interceptions', 'Positioning', 'Vision',
#        'Penalties', 'Composure', 'Defending', 'Marking', 'Standing Tackle',
#        'Sliding Tackle', 'Goalkeeping', 'GK Diving', 'GK Handling',
#        'GK Kicking', 'GK Positioning', 'GK Reflexes', 'Total Stats',
# ...

# %%
df8= df[['D/W', 'IR', 'PAC', 'SHO', 'PAS','DRI', 'DEF', 'PHY', 'Hits']]

# %%
df8.head()
# Out:
#       D/W   IR  PAC  SHO  PAS  DRI  DEF  PHY Hits
# 0     Low  5 ★   85   92   91   95   38   65  771
# 1     Low  5 ★   89   93   81   89   35   77  562
# 2  Medium  3 ★   87   92   78   90   52   90  150
# 3    High  4 ★   76   86   93   88   64   78  207
# 4  Medium  5 ★   91   85   86   94   36   59  595

# %%
df8.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18979 entries, 0 to 18978
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   D/W     18979 non-null  object
#  1   IR      18979 non-null  object
#  2   PAC     18979 non-null  int64
#  3   SHO     18979 non-null  int64
#  4   PAS     18979 non-null  int64
#  5   DRI     18979 non-null  int64
#  6   DEF     18979 non-null  int64
#  7   PHY     18979 non-null  int64
#  8   Hits    16384 non-null  object
# dtypes: int64(6), object(3)
# memory usage: 1.3+ MB

# %%
df8.dtypes
# Out:
# D/W     object
# IR      object
# PAC      int64
# SHO      int64
# PAS      int64
# DRI      int64
# DEF      int64
# PHY      int64
# Hits    object
# dtype: object

# %%
df8.describe()
# Out:
#                 PAC           SHO           PAS           DRI           DEF  \
# count  18979.000000  18979.000000  18979.000000  18979.000000  18979.000000
# mean      67.453975     53.457031     57.681016     62.875020     49.866221
# std       10.677859     13.827425     10.081857      9.927415     16.443213
# min       25.000000     16.000000     25.000000     25.000000     12.000000
# 25%       61.000000     44.000000     51.000000     57.000000     35.000000
# 50%       68.000000     56.000000     58.000000     64.000000     53.000000
# 75%       75.000000     64.000000     64.000000     69.000000     63.000000
# max       96.000000     93.000000     93.000000     95.000000     91.000000
#
#                 PHY
# count  18979.000000
# mean      64.368934
# std        9.601883
# min       28.000000
# 25%       58.000000
# 50%       65.000000
# 75%       71.000000
# max       91.000000

# %%
df8.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Great! There are no duplicated values in the dataset

# %%
df8.isna().sum()
# Out:
# D/W        0
# IR         0
# PAC        0
# SHO        0
# PAS        0
# DRI        0
# DEF        0
# PHY        0
# Hits    2595
# dtype: int64

# %%
# Visualizing missing values in a heatmap

sns.heatmap(df8.isnull(),yticklabels=False,cbar=False)
# Out:
# <AxesSubplot:>

# %% [markdown]
# The Hits column has soo many missing values Lets drop it

# %%
# Drop the Hits column column
df8 = df8.drop(['Hits'], axis=1)

# %%
df8.isna().sum()
# Out:
# D/W    0
# IR     0
# PAC    0
# SHO    0
# PAS    0
# DRI    0
# DEF    0
# PHY    0
# dtype: int64

# %% [markdown]
# Perfect! The column has been eliminated successfully

# %% [markdown]
# # Checking for unique values in the columns

# %%
df8['D/W'].unique()
# Out:
# array(['Low', 'Medium', 'High'], dtype=object)

# %%
df8['IR'].unique()
# Out:
# array(['5 ★', '3 ★', '4 ★', '2 ★', '1 ★'], dtype=object)

# %%
df8['PAC'].unique()
# Out:
# array([85, 89, 87, 76, 91, 78, 93, 86, 96, 88, 94, 65, 84, 74, 71, 77, 68,
#        75, 54, 79, 83, 80, 81, 82, 63, 67, 90, 66, 42, 73, 70, 64, 57, 58,
#        69, 72, 50, 59, 92, 60, 62, 55, 52, 56, 61, 53, 45, 37, 95, 43, 44,
#        46, 48, 49, 47, 34, 39, 40, 51, 41, 36, 32, 33, 30, 31, 38, 35, 28,
#        29, 25], dtype=int64)

# %%
df8['SHO'].unique()
# Out:
# array([92, 93, 86, 85, 91, 88, 60, 73, 89, 87, 70, 90, 81, 66, 72, 82, 28,
#        74, 77, 62, 50, 83, 69, 80, 46, 76, 54, 49, 61, 58, 79, 68, 59, 41,
#        45, 64, 78, 55, 75, 65, 63, 48, 42, 56, 51, 30, 47, 84, 40, 57, 25,
#        71, 37, 43, 53, 67, 38, 52, 39, 35, 36, 44, 32, 34, 33, 31, 27, 22,
#        29, 26, 23, 18, 24, 20, 16, 21, 19, 17], dtype=int64)

# %%
df8['PAS'].unique()
# Out:
# array([91, 81, 78, 93, 86, 85, 88, 71, 80, 76, 74, 77, 79, 84, 73, 55, 83,
#        87, 72, 75, 58, 89, 82, 68, 67, 64, 66, 59, 69, 90, 65, 53, 63, 62,
#        70, 56, 42, 54, 61, 57, 60, 48, 52, 47, 46, 44, 45, 50, 51, 49, 43,
#        36, 38, 40, 41, 35, 39, 34, 33, 37, 30, 32, 29, 31, 26, 28, 25, 27],
#       dtype=int64)

# %%
df8['DRI'].unique()
# Out:
# array([95, 89, 90, 88, 94, 85, 91, 71, 72, 86, 73, 81, 84, 92, 80, 68, 77,
#        87, 60, 83, 78, 64, 67, 79, 69, 66, 65, 70, 82, 75, 61, 74, 54, 76,
#        49, 63, 59, 62, 56, 55, 50, 57, 58, 52, 53, 51, 48, 47, 46, 39, 44,
#        43, 36, 40, 45, 41, 37, 34, 35, 42, 32, 38, 31, 33, 30, 29, 28, 25,
#        27], dtype=int64)

# %%
df8['DEF'].unique()
# Out:
# array([38, 35, 52, 64, 36, 43, 45, 51, 39, 91, 44, 86, 48, 57, 40, 88, 33,
#        81, 63, 47, 53, 89, 71, 37, 80, 68, 85, 61, 90, 83, 49, 56, 58, 82,
#        87, 79, 66, 55, 78, 32, 50, 76, 77, 70, 75, 41, 29, 73, 65, 59, 84,
#        54, 72, 46, 42, 69, 34, 31, 30, 74, 24, 62, 25, 20, 26, 60, 27, 23,
#        28, 67, 22, 19, 18, 21, 17, 15, 16, 12], dtype=int64)

# %%
df8['PHY'].unique()
# Out:
# array([65, 77, 90, 78, 59, 82, 75, 91, 76, 88, 86, 85, 73, 67, 79, 63, 83,
#        89, 66, 69, 72, 64, 71, 81, 87, 68, 84, 80, 55, 70, 44, 62, 51, 57,
#        60, 58, 56, 74, 52, 61, 53, 45, 50, 54, 47, 48, 49, 42, 37, 40, 39,
#        43, 38, 46, 41, 34, 35, 36, 31, 32, 33, 29, 28], dtype=int64)

# %% [markdown]
# # Checking for outliers in the columns

# %%
# boxplot of PHY column

df8.boxplot(column= 'PHY')
plt.ylabel("Player's PHY")
plt.title("Player's PHY Boxplot")
plt.show()

# %%
# First quartile\
Q1 = df8['PHY'].quantile(0.25)

# Second Quartile

Q3 = df8['PHY'].quantile(0.75)

# interquartile range

IQR = Q3 - Q1

# IQR
IQR
# Out:
# 13.0

# %%
# whisker width

whisker_width = 1.5


# get the outlier records in dataset

PHY_outliers = df8[(df8['PHY'] < (Q1 - (whisker_width*IQR))) | (df8['PHY'] > (Q3 + (whisker_width*IQR)))]


# records with PHY outliers

PHY_outliers['PHY'].to_list()
# Out:
# [91,
#  91,
#  91,
#  37,
#  38,
#  91,
#  34,
#  35,
#  36,
#  38,
#  36,
#  37,
#  31,
#  35,
#  35,
#  38,
#  31,
#  37,
#  38,
#  37,
#  36,
#  38,
#  34,
#  34,
#  37,
#  38,
#  32,
#  37,
#  36,
#  33,
#  38,
#  33,
#  38,
#  38,
#  34,
#  36,
#  33,
#  38,
#  36,
#  37,
#  29,
#  37,
#  36,
#  36,
#  33,
#  33,
#  35,
#  38,
#  38,
#  38,
#  38,
#  37,
#  36,
#  38,
#  36,
#  38,
#  31,
#  38,
#  36,
#  38,
#  28,
#  38,
#  38,
#  36,
#  38,
#  38,
#  37,
#  38,
#  36,
#  38,
#  38,
#  28,
#  38,
#  38,
#  34,
#  37,
#  29,
#  37,
#  37,
#  38,
#  38,
#  38,
#  37,
#  35,
#  38,
#  37,
#  37,
#  34,
#  38,
#  36,
#  38,
#  34,
#  36,
#  35,
#  37,
#  38,
#  37,
#  36,
#  38,
#  38,
#  38,
#  38,
#  37,
#  37,
#  37,
#  35,
#  36,
#  33,
#  38,
#  36,
#  34,
#  34,
#  34,
#  35,
#  34,
#  35,
#  37]

# %% [markdown]
# The outliers lie on the values above 90 and the values below 39

# %% [markdown]
# Eliminating the outliers

# %%
# whisker width
whisker_width = 1.5

# get the outlier records PHY in dataset
PHY_outliers = df8[(df8['PHY'] < (Q1 - (whisker_width*IQR))) | (df8['PHY'] > (Q3 + (whisker_width*IQR)))]

# drop the outliers
df8 = df8.drop(PHY_outliers.index)

# show the updated boxplot without outliers
df8.boxplot(column='PHY')
plt.ylabel("Player's PHY")
plt.title("Player's PHY​  Boxplot (without outliers)")
plt.show()

# %% [markdown]
# Outliers successfully eliminated

# %%
# boxplot of DEF column

df8.boxplot(column= 'DEF')
plt.ylabel("Player's DEF")
plt.title("Player's DEF Boxplot")
plt.show()

# %% [markdown]
# There are no outliers in the DEF Column

# %%
# boxplot of DRI column

df8.boxplot(column= 'DRI')
plt.ylabel("Player's DRI")
plt.title("Player's DRI Boxplot")
plt.show()

# %%
# First quartile\
Q1 = df8['DRI'].quantile(0.25)

# Second Quartile

Q3 = df8['DRI'].quantile(0.75)

# interquartile range

IQR = Q3 - Q1

# IQR
IQR
# Out:
# 12.0

# %%
# whisker width

whisker_width = 1.5


# get the outlier records in dataset

DRI_outliers = df8[(df8['DRI'] < (Q1 - (whisker_width*IQR))) | (df8['DRI'] > (Q3 + (whisker_width*IQR)))]


# records with DRI outliers

DRI_outliers['DRI'].to_list()
# Out:
# [95,
#  89,
#  90,
#  88,
#  94,
#  90,
#  91,
#  90,
#  90,
#  88,
#  89,
#  88,
#  90,
#  92,
#  88,
#  89,
#  92,
#  88,
#  91,
#  92,
#  90,
#  90,
#  88,
#  88,
#  88,
#  90,
#  89,
#  90,
#  88,
#  88,
#  89,
#  90,
#  91,
#  90,
#  89,
#  88,
#  90,
#  88,
#  91,
#  89,
#  88,
#  88,
#  89,
#  88,
#  88,
#  88,
#  88,
#  88,
#  36,
#  37,
#  34,
#  35,
#  36,
#  37,
#  35,
#  36,
#  36,
#  35,
#  37,
#  32,
#  37,
#  37,
#  38,
#  38,
#  35,
#  31,
#  38,
#  38,
#  38,
#  37,
#  38,
#  34,
#  37,
#  37,
#  38,
#  31,
#  35,
#  36,
#  35,
#  38,
#  36,
#  33,
#  38,
#  38,
#  38,
#  36,
#  38,
#  33,
#  36,
#  31,
#  37,
#  36,
#  34,
#  35,
#  32,
#  38,
#  38,
#  32,
#  35,
#  35,
#  37,
#  36,
#  35,
#  38,
#  38,
#  37,
#  36,
#  34,
#  37,
#  37,
#  37,
#  38,
#  38,
#  35,
#  35,
#  36,
#  31,
#  37,
#  36,
#  30,
#  33,
#  38,
#  38,
#  33,
#  36,
#  37,
#  32,
#  34,
#  37,
#  38,
#  35,
#  37,
#  37,
#  33,
#  36,
#  37,
#  33,
#  33,
#  32,
#  36,
#  37,
#  38,
# ...

# %% [markdown]
# The outliers are on the columns above 87 and below 39

# %% [markdown]
# Eliminating the outliers

# %%
# whisker width
whisker_width = 1.5

# get the outlier records PHY in dataset
DRI_outliers = df8[(df8['DRI'] < (Q1 - (whisker_width*IQR))) | (df8['DRI'] > (Q3 + (whisker_width*IQR)))]

# drop the outliers
df8 = df8.drop(DRI_outliers.index)

# show the updated boxplot without outliers
df8.boxplot(column='DRI')
plt.ylabel("Player's DRI")
plt.title("Player's DRI​  Boxplot (without outliers)")
plt.show()

# %% [markdown]
# Eliminated successfully

# %%
# boxplot of PAS column

df8.boxplot(column= 'PAS')
plt.ylabel("Player's PAS")
plt.title("Player's PASBoxplot")
plt.show()

# %%
# First quartile\
Q1 = df8['PAS'].quantile(0.25)

# Second Quartile

Q3 = df8['PAS'].quantile(0.75)

# interquartile range

IQR = Q3 - Q1

# IQR
IQR
# Out:
# 13.0

# %%
# whisker width

whisker_width = 1.5


# get the outlier records in dataset

PAS_outliers = df8[(df8['PAS'] < (Q1 - (whisker_width*IQR))) | (df8['PAS'] > (Q3 + (whisker_width*IQR)))]


# records with PAS outliers

PAS_outliers['PAS'].to_list()
# Out:
# [86,
#  91,
#  87,
#  88,
#  86,
#  85,
#  87,
#  90,
#  85,
#  88,
#  86,
#  87,
#  87,
#  86,
#  85,
#  85,
#  85,
#  85,
#  87,
#  85,
#  85,
#  87,
#  85,
#  90,
#  30,
#  32,
#  31,
#  31,
#  29,
#  32,
#  32,
#  32,
#  26,
#  31,
#  32,
#  29,
#  25,
#  31,
#  32,
#  32,
#  32,
#  32,
#  32,
#  32,
#  30,
#  31,
#  32,
#  28,
#  27,
#  29,
#  30,
#  31,
#  30,
#  32,
#  30,
#  32,
#  32,
#  32,
#  32,
#  31,
#  30,
#  27,
#  30,
#  30,
#  32,
#  28]

# %% [markdown]
# The outliers lie on the values above 83 and the values below 32

# %% [markdown]
# Eliminating the outliers

# %%
# whisker width
whisker_width = 1.5

# get the outlier records PHY in dataset
PAS_outliers = df8[(df8['PAS'] < (Q1 - (whisker_width*IQR))) | (df8['PAS'] > (Q3 + (whisker_width*IQR)))]

# drop the outliers
df8 = df8.drop(PAS_outliers.index)

# show the updated boxplot without outliers
df8.boxplot(column='PAS')
plt.ylabel("Player's PAS")
plt.title("Player's PAS​  Boxplot (without outliers)")
plt.show()

# %% [markdown]
# Outliers eliminated successfully

# %%
# boxplot of SHO column

df8.boxplot(column= 'SHO')
plt.ylabel("Player's SHO")
plt.title("Player's SHO Boxplot")
plt.show()

# %% [markdown]
# There are no outliers on the SHO column

# %%
# boxplot of PAC column

df8.boxplot(column= 'PAC')
plt.ylabel("Player's PAC")
plt.title("Player's PAC Boxplot")
plt.show()

# %%
# First quartile\
Q1 = df8['PAC'].quantile(0.25)

# Second Quartile

Q3 = df8['PAC'].quantile(0.75)

# interquartile range

IQR = Q3 - Q1

# IQR
IQR
# Out:
# 13.0

# %%
# whisker width

whisker_width = 1.5


# get the outlier records in dataset

PAC_outliers = df8[(df8['PAC'] < (Q1 - (whisker_width*IQR))) | (df8['PAC'] > (Q3 + (whisker_width*IQR)))]


# records with PAC outliers

PAC_outliers['PAC'].to_list()
# Out:
# [42,
#  96,
#  37,
#  95,
#  96,
#  37,
#  34,
#  39,
#  40,
#  41,
#  36,
#  32,
#  41,
#  33,
#  37,
#  33,
#  34,
#  95,
#  33,
#  42,
#  40,
#  36,
#  33,
#  37,
#  34,
#  37,
#  42,
#  30,
#  33,
#  33,
#  34,
#  42,
#  41,
#  36,
#  31,
#  41,
#  41,
#  36,
#  38,
#  37,
#  31,
#  37,
#  40,
#  37,
#  38,
#  42,
#  32,
#  33,
#  30,
#  34,
#  34,
#  39,
#  42,
#  30,
#  37,
#  39,
#  37,
#  41,
#  38,
#  41,
#  39,
#  32,
#  39,
#  32,
#  31,
#  39,
#  30,
#  39,
#  32,
#  33,
#  40,
#  41,
#  35,
#  33,
#  32,
#  42,
#  39,
#  39,
#  34,
#  33,
#  30,
#  34,
#  33,
#  41,
#  35,
#  41,
#  35,
#  32,
#  39,
#  34,
#  35,
#  34,
#  37,
#  31,
#  34,
#  40,
#  32,
#  38,
#  35,
#  42,
#  37,
#  39,
#  40,
#  42,
#  35,
#  41,
#  32,
#  33,
#  36,
#  34,
#  34,
#  38,
#  38,
#  35,
#  32,
#  36,
#  32,
#  42,
#  34,
#  34,
#  40,
#  33,
#  33,
#  34,
#  39,
#  34,
#  35,
#  30,
#  34,
#  31,
#  34,
#  41,
#  34,
#  42,
#  39,
#  31,
#  32,
#  35,
#  31,
#  38,
#  40,
#  41,
# ...

# %% [markdown]
# The outliers are the values below 40

# %% [markdown]
# Eliminating the outliers

# %%
# whisker width
whisker_width = 1.5

# get the outlier records PHY in dataset
PAC_outliers = df8[(df8['PAC'] < (Q1 - (whisker_width*IQR))) | (df8['PAC'] > (Q3 + (whisker_width*IQR)))]

# drop the outliers
df8 = df8.drop(PAC_outliers.index)

# show the updated boxplot without outliers
df8.boxplot(column='PAC')
plt.ylabel("Player's PAC")
plt.title("Player's PAC​  Boxplot (without outliers)")
plt.show()

# %% [markdown]
# Outliers eliminated successfully

# %% [markdown]
# Saving the dataset csv file

# %%
# Save the dataset to a CSV file
df8.to_csv('df8_dataset.csv', index=False)

# %% [markdown]
# # Finalization Detailed Cleaning now

# %% [markdown]
# Great! The columns have been dropped successfully

# %% [markdown]
# # Combining the cleaned dataset to form one final dataset

# %% [markdown]
# Loading the datasets

# %%
df9 = pd.read_csv('df9_dataset.csv')
df2 = pd.read_csv('df2_dataset.csv')

df3 = pd.read_csv('df3_dataset.csv')
df4 = pd.read_csv('df4_dataset.csv')
df5 = pd.read_csv('df5_dataset.csv')
df6 = pd.read_csv('df6_dataset.csv')
df7 = pd.read_csv('df7_dataset.csv')
df8 = pd.read_csv('df8_dataset.csv')

# %%
print(df2.columns)
print(df3.columns)
print(df4.columns)
print(df5.columns)
print(df6.columns)
print(df7.columns)
print(df8.columns)
print(df9.columns)
# Out:
# Index(['Contract', 'Positions', 'Height', 'Weight', 'Preferred Foot', 'BOV',
#        'Best Position', 'Joined', 'Value'],
#       dtype='object')
# Index(['Wage', 'Release Clause', 'Attacking', 'Crossing', 'Finishing',
#        'Heading Accuracy', 'Short Passing', 'Volleys', 'Skill', 'Dribbling'],
#       dtype='object')
# Index(['Curve', 'FK Accuracy', 'Long Passing', 'Ball Control', 'Movement',
#        'Acceleration', 'Sprint Speed', 'Agility', 'Reactions'],
#       dtype='object')
# Index(['Balance', 'Power', 'Shot Power', 'Jumping', 'Stamina', 'Strength',
#        'Long Shots', 'Mentality', 'Aggression', 'Interceptions'],
#       dtype='object')
# Index(['Positioning', 'Vision', 'Penalties', 'Composure', 'Defending',
#        'Marking', 'Standing Tackle', 'Sliding Tackle', 'Goalkeeping'],
#       dtype='object')
# Index(['GK Diving', 'GK Handling', 'GK Kicking', 'GK Positioning',
#        'GK Reflexes', 'Total Stats', 'Base Stats', 'W/F', 'SM', 'A/W'],
#       dtype='object')
# ...

# %%
# Define the list of datasets
datasets = [df2, df3, df4, df5, df6, df7, df8, df9]

# Loop through each dataset and print its shape
for dataset in datasets:
    print(dataset.shape)
# Out:
# (18979, 9)
# (16952, 10)
# (16023, 9)
# (15038, 10)
# (15564, 9)
# (16848, 10)
# (17930, 8)
# (18971, 10)

# %%
# Define the list of datasets
datasets = [df2, df3, df4, df5, df6, df7, df8, df9]

# Find the minimum number of rows across all datasets
min_rows = min([dataset.shape[0] for dataset in datasets])

# Slice each dataset to keep only the first `min_rows` rows
for i in range(len(datasets)):
    datasets[i] = datasets[i].iloc[:min_rows, :]

# Concatenate the datasets horizontally (i.e. along columns) into a single dataframe
combined_df = pd.concat(datasets, axis=1)

# %%
combined_df.tail()
# Out:
#           Contract Positions  Height  Weight Preferred Foot  BOV  \
# 15033  2019 ~ 2021        LB   182.0  176.32           Left   60
# 15034  2020 ~ 2021        CB   190.0  182.93          Right   62
# 15035  2019 ~ 2021   CDM, CM   170.0  154.28           Left   62
# 15036  2017 ~ 2020   CDM, CM   178.0  158.69          Right   60
# 15037  2020 ~ 2024        RB   178.0  149.87          Right   60
#
#       Best Position        Joined   Value  Wage  ...      ID            Name  \
# 15033            LB   Dec 8, 2019  525000  2000  ...  253270        G. Viera
# 15034            CB  Aug 20, 2020  500000  1000  ...  241239   Lin Liangming
# 15035            CM   Jul 1, 2019  275000  1000  ...  247639       E. Cuello
# 15036           CDM   Jan 1, 2017  170000  1000  ...  257111   J. Le Douaron
# 15037            RB  Jul 30, 2020  525000  2000  ...  255318  N. Billingsley
#
#                 LongName                                          photoUrl  \
# ...

# %%
combined_df.shape
# Out:
# (15038, 75)

# %%
combined_df.isna().sum()
# Out:
# Contract          0
# Positions         0
# Height            0
# Weight            0
# Preferred Foot    0
#                  ..
# Nationality       0
# Age               0
# ↓OVA              0
# POT               0
# Club              0
# Length: 75, dtype: int64

# %%
combined_df.describe()
# Out:
#              Height        Weight           BOV         Value           Wage  \
# count  15038.000000  15038.000000  15038.000000  1.503800e+04   15038.000000
# mean     181.315970    166.380170     69.127078  2.191941e+07   10311.856630
# std        6.860149     15.593348      5.246077  6.244351e+07   20014.959751
# min      155.000000    110.200000     60.000000  0.000000e+00       0.000000
# 25%      176.000000    154.280000     65.000000  7.250000e+05    2000.000000
# 50%      181.000000    165.300000     68.000000  1.100000e+07    4000.000000
# 75%      186.000000    176.320000     72.000000  1.900000e+07   10000.000000
# max      206.000000    242.440000     93.000000  1.855000e+09  370000.000000
#
#        Release Clause     Attacking      Crossing     Finishing  \
# count    1.503800e+04  15038.000000  15038.000000  15038.000000
# mean     3.893061e+07    276.244248     55.597087     51.184865
# std      9.620524e+07     43.849283     13.500376     16.207334
# ...

# %% [markdown]
# The url columns are not necessary now let's drop them

# %%
# Drop the Loan Date end column column
combined_df = combined_df.drop(['photoUrl'], axis=1)

# %%
# Drop the Loan Date end column column
combined_df = combined_df.drop(['playerUrl'], axis=1)

# %%
combined_df.head()
# Out:
#       Contract   Positions  Height  Weight Preferred Foot  BOV Best Position  \
# 0  2004 ~ 2021  RW, ST, CF   170.0  158.69           Left   93            RW
# 1  2018 ~ 2022      ST, LW   187.0  182.93          Right   92            ST
# 2  2014 ~ 2023          GK   188.0  191.75          Right   91            GK
# 3  2015 ~ 2023     CAM, CM   181.0  154.28          Right   91           CAM
# 4  2017 ~ 2022     LW, CAM   175.0  149.87          Right   91            LW
#
#          Joined       Value    Wage  ...  DEF  PHY      ID               Name  \
# 0   Jul 1, 2004  1035000000  370000  ...   43   82  158023           L. Messi
# 1  Jul 10, 2018    63000000  270000  ...   91   86   20801  Cristiano Ronaldo
# 2  Jul 16, 2014   120000000  250000  ...   40   76  200389           J. Oblak
# 3  Aug 30, 2015   129000000  160000  ...   88   85  192985       K. De Bruyne
# 4   Aug 3, 2017   132000000  160000  ...   86   82  190871          Neymar Jr
#
# ...

# %% [markdown]
# successfully dropped

# %% [markdown]
# since the dataset is clean we can now save it

# %%
# Save the dataset to a CSV file
combined_df.to_csv('clean_Fifa_Data.csv', index=False)
